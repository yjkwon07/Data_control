# %%
import pandas as pd
df = pd.read_csv('data-zillow.csv', sep=',', engine='python')

# %%
df.axes # list
# Out:
# [RangeIndex(start=0, stop=10830, step=1),
#  Index(['Date', 'RegionID', 'RegionName', 'State', 'Metro', 'County',
#         'SizeRank', 'Zhvi'],
#        dtype='object')]

# %%
len(df.axes)
# Out:
# 2

# %%
#판다스에서는 워소가 2개 있으면 앞은 행 뒤는 열

# %%
# row와 col의 명세를 볼 때 axes

# %%
df.axes[1]
# Out:
# Index(['Date', 'RegionID', 'RegionName', 'State', 'Metro', 'County',
#        'SizeRank', 'Zhvi'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Date', 'RegionID', 'RegionName', 'State', 'Metro', 'County',
#        'SizeRank', 'Zhvi'],
#       dtype='object')

# %%
# axes는 전부 인데긋
# 큰틀은 dataframe [series, series]

# %%
df.mean(axis= 0) # info에서 숫자로 나온애들만  # 전체 컬럼의 숫자값만의 개수
# Out:
# RegionID     84344.818837
# SizeRank      5414.500000
# Zhvi        250307.590028
# dtype: float64

# %%
df.mean(axis=1) # 전체 행만큼의 개수
# Out:
# 0        2.261937e+05
# 1        2.141160e+05
# 2        8.004267e+04
# 3        5.019133e+04
# 4        8.387667e+04
# 5        7.848800e+04
# 6        2.088007e+05
# 7        6.761167e+04
# 8        3.037490e+05
# 9        5.919967e+04
# 10       4.048800e+05
# 11       1.106107e+05
# 12       1.975800e+04
# 13       4.641100e+04
# 14       3.797500e+04
# 15       6.928600e+04
# 16       4.378300e+04
# 17       1.996287e+05
# 18       2.287850e+05
# 19       4.154733e+04
# 20       1.314377e+05
# 21       1.991630e+05
# 22       7.821333e+04
# 23       3.796633e+04
# 24       5.743500e+04
# 25       1.437660e+05
# 26       5.531700e+04
# 27       6.409300e+04
# 28       7.101900e+04
# 29       7.697733e+04
#              ...
# 10800    9.508133e+04
# 10801    4.300067e+04
# 10802    1.580057e+05
# 10803    1.068157e+05
# 10804    1.228323e+05
# 10805    6.629900e+04
# 10806    1.105600e+05
# 10807    4.130633e+04
# 10808    3.759180e+05
# 10809    3.538200e+04
# ...

# %%
df['RegionID'].max() # 1차원 시리즈이기 때문에 axies 필요없다 .dataframe에 관련된것만 axis
# Out:
# 737791

# %%
df.mean(axis='rows')
# Out:
# RegionID     84344.818837
# SizeRank      5414.500000
# Zhvi        250307.590028
# dtype: float64

# %%
df.mean(axis='columns').head()
# Out:
# 0    226193.666667
# 1    214116.000000
# 2     80042.666667
# 3     50191.333333
# 4     83876.666667
# dtype: float64

# %%
df.filter(regex='Region', axis=1)
# Out:
#        RegionID         RegionName
# 0          6181           New York
# 1         12447        Los Angeles
# 2         17426            Chicago
# 3         13271       Philadelphia
# 4         40326            Phoenix
# 5         18959          Las Vegas
# 6         54296          San Diego
# 7         38128             Dallas
# 8         33839           San Jose
# 9         25290       Jacksonville
# 10        20330      San Francisco
# 11        10221             Austin
# 12        17762            Detroit
# 13        10920           Columbus
# 14        32811            Memphis
# 15        24043          Charlotte
# 16        17933            El Paso
# 17        44269             Boston
# 18        16037            Seattle
# 19         3523          Baltimore
# 20        11093             Denver
# 21        41568         Washington
# 22         6118          Nashville
# 23         5976          Milwaukee
# 24         7481             Tucson
# 25        13373           Portland
# ...

# %%
df.filter(regex='([0-9])', axis=1)  # 숫자 3자리
# Out:
#              Date  RegionID         RegionName State  \
# 0      2017-05-31      6181           New York    NY
# 1      2017-05-31     12447        Los Angeles    CA
# 2      2017-05-31     17426            Chicago    IL
# 3      2017-05-31     13271       Philadelphia    PA
# 4      2017-05-31     40326            Phoenix    AZ
# 5      2017-05-31     18959          Las Vegas    NV
# 6      2017-05-31     54296          San Diego    CA
# 7      2017-05-31     38128             Dallas    TX
# 8      2017-05-31     33839           San Jose    CA
# 9      2017-05-31     25290       Jacksonville    FL
# 10     2017-05-31     20330      San Francisco    CA
# 11     2017-05-31     10221             Austin    TX
# 12     2017-05-31     17762            Detroit    MI
# 13     2017-05-31     10920           Columbus    OH
# 14     2017-05-31     32811            Memphis    TN
# 15     2017-05-31     24043          Charlotte    NC
# 16     2017-05-31     17933            El Paso    TX
# ...

# %%
df2 = pd.read_csv('data-netflix.csv', index_col='title' ,engine='python')

# %%
df2
# Out:
#                                            rating  \
# title
# White Chicks                                PG-13
# Lucky Number Slevin                             R
# Grey's Anatomy                              TV-14
# Prison Break                                TV-14
# How I Met Your Mother                       TV-PG
# Supernatural                                TV-14
# Breaking Bad                                TV-MA
# The Vampire Diaries                         TV-14
# The Walking Dead                            TV-MA
# Pretty Little Liars                         TV-14
# Once Upon a Time                            TV-PG
# Sherlock                                    TV-14
# Death Note                                  TV-14
# Naruto                                      TV-PG
# The Hunter                                      R
# Lottie Dottie Chicken                        TV-Y
# Arrow                                       TV-14
# Black Mirror                                TV-MA
# ...

# %%
df2.filter(regex='BFG', axis=0)
# Out:
#         rating                                        ratingLevel  \
# title
# The BFG     PG  for action/peril, some scary moments and brief...
# The BFG     PG  for action/peril, some scary moments and brief...
#
#          ratingDescription  release year  user rating score  user rating size
# title
# The BFG                 60          2016               97.0                80
# The BFG                 60          2016               97.0                80

# %%
data2 = df[['year', 'price']]

# %%
data2.year().mean()
