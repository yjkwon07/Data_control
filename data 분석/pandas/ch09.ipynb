# %%
import pandas as pd

# %%
df = pd.read_csv('pew.txt', sep ='\t')

# %%
df = df.set_index('religion')

# %%
df
# Out:
#                          <$10k  $10-20k  $20-30k  $30-40k  $40-50k  $50-75k  \
# religion
# Agnostic                    27       34       60       81       76      137
# Atheist                     12       27       37       52       35       70
# Buddhist                    27       21       30       34       33       58
# Catholic                   418      617      732      670      638     1116
# Don’t know/refused          15       14       15       11       10       35
# Evangelical Prot           575      869     1064      982      881     1486
# Hindu                        1        9        7        9       11       34
# Historically Black Prot    228      244      236      238      197      223
# Jehovah's Witness           20       27       24       24       21       30
# Jewish                      19       19       25       25       30       95
# Mainline Prot              289      495      619      655      651     1107
# ...

# %%
df =df.stack()

# %%
df #series # 한열로 쫙 쌓는거야 # axixs = index
# Out:
# religion
# Agnostic               <$10k                  27
#                        $10-20k                34
#                        $20-30k                60
#                        $30-40k                81
#                        $40-50k                76
#                        $50-75k               137
#                        $75-100k              122
#                        $100-150k             109
#                        >150k                  84
#                        Don't know/refused     96
# Atheist                <$10k                  12
#                        $10-20k                27
#                        $20-30k                37
#                        $30-40k                52
#                        $40-50k                35
#                        $50-75k                70
#                        $75-100k               73
#                        $100-150k              59
#                        >150k                  74
# ...

# %%
df = df.unstack()

# %%
df # axis = column
# Out:
#                     religion
# <$10k               Agnostic                     27
#                     Atheist                      12
#                     Buddhist                     27
#                     Catholic                    418
#                     Don’t know/refused           15
#                     Evangelical Prot            575
#                     Hindu                         1
#                     Historically Black Prot     228
#                     Jehovah's Witness            20
#                     Jewish                       19
#                     Mainline Prot               289
#                     Mormon                       29
#                     Muslim                        6
#                     Orthodox                     13
#                     Other Christian               9
#                     Other Faiths                 20
#                     Other World Religions         5
# ...

# %%
df.index
# Out:
# Index(['Agnostic', 'Atheist', 'Buddhist', 'Catholic', 'Don’t know/refused',
#        'Evangelical Prot', 'Hindu', 'Historically Black Prot',
#        'Jehovah's Witness', 'Jewish', 'Mainline Prot', 'Mormon', 'Muslim',
#        'Orthodox', 'Other Christian', 'Other Faiths', 'Other World Religions',
#        'Unaffiliated'],
#       dtype='object', name='religion')

# %%
df.index = df.index.rename('A')

# %%
df.index
# Out:
# Index(['Agnostic', 'Atheist', 'Buddhist', 'Catholic', 'Don’t know/refused',
#        'Evangelical Prot', 'Hindu', 'Historically Black Prot',
#        'Jehovah's Witness', 'Jewish', 'Mainline Prot', 'Mormon', 'Muslim',
#        'Orthodox', 'Other Christian', 'Other Faiths', 'Other World Religions',
#        'Unaffiliated'],
#       dtype='object', name='A')

# %%
df.<$10k # 연산자 우선순위 겹치기 때문에 딕셔너리 사용
# Out:
#   File "<ipython-input-20-68506635f693>", line 1
#     df.<$10k # 연산자 우선순위 겹치기 때문에 딕셔너리 사용
#        ^
# SyntaxError: invalid syntax

# %%
a = df['<$10k']

# %%
a.rename('BBB')
# Out:
# A
# Agnostic                    27
# Atheist                     12
# Buddhist                    27
# Catholic                   418
# Don’t know/refused          15
# Evangelical Prot           575
# Hindu                        1
# Historically Black Prot    228
# Jehovah's Witness           20
# Jewish                      19
# Mainline Prot              289
# Mormon                      29
# Muslim                       6
# Orthodox                    13
# Other Christian              9
# Other Faiths                20
# Other World Religions        5
# Unaffiliated               217
# Name: BBB, dtype: int64

# %%
df # 반영이 안됨 df자체 rename 해야한다.
# Out:
#                          <$10k  $10-20k  $20-30k  $30-40k  $40-50k  $50-75k  \
# A
# Agnostic                    27       34       60       81       76      137
# Atheist                     12       27       37       52       35       70
# Buddhist                    27       21       30       34       33       58
# Catholic                   418      617      732      670      638     1116
# Don’t know/refused          15       14       15       11       10       35
# Evangelical Prot           575      869     1064      982      881     1486
# Hindu                        1        9        7        9       11       34
# Historically Black Prot    228      244      236      238      197      223
# Jehovah's Witness           20       27       24       24       21       30
# Jewish                      19       19       25       25       30       95
# Mainline Prot              289      495      619      655      651     1107
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18 entries, Agnostic to Unaffiliated
# Data columns (total 10 columns):
# <$10k                 18 non-null int64
# $10-20k               18 non-null int64
# $20-30k               18 non-null int64
# $30-40k               18 non-null int64
# $40-50k               18 non-null int64
# $50-75k               18 non-null int64
# $75-100k              18 non-null int64
# $100-150k             18 non-null int64
# >150k                 18 non-null int64
# Don't know/refused    18 non-null int64
# dtypes: int64(10)
# memory usage: 2.2+ KB

# %%
df['<$10k'] = df['<$10k'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18 entries, Agnostic to Unaffiliated
# Data columns (total 10 columns):
# <$10k                 18 non-null category
# $10-20k               18 non-null int64
# $20-30k               18 non-null int64
# $30-40k               18 non-null int64
# $40-50k               18 non-null int64
# $50-75k               18 non-null int64
# $75-100k              18 non-null int64
# $100-150k             18 non-null int64
# >150k                 18 non-null int64
# Don't know/refused    18 non-null int64
# dtypes: category(1), int64(9)
# memory usage: 2.8+ KB

# %%
df.describe()
# Out:
#           $10-20k      $20-30k     $30-40k     $40-50k      $50-75k  \
# count   18.000000    18.000000   18.000000   18.000000    18.000000
# mean   154.500000   186.500000  183.444444  171.388889   288.055556
# std    255.172433   309.891869  291.470354  271.144446   458.442436
# min      2.000000     3.000000    4.000000    2.000000     7.000000
# 25%     14.750000    17.000000   15.750000   15.000000    34.250000
# 50%     27.000000    33.500000   40.000000   34.000000    66.500000
# 75%    193.000000   192.000000  198.750000  166.750000   201.500000
# max    869.000000  1064.000000  982.000000  881.000000  1486.000000
#
#          $75-100k   $100-150k       >150k  Don't know/refused
# count   18.000000   18.000000   18.000000           18.000000
# mean   221.666667  177.611111  144.888889          340.055556
# std    345.078849  275.679724  205.224952          530.523878
# min      3.000000    4.000000    4.000000            8.000000
# ...

# %%
df.category = df['<$10k']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %%
df.category = df.category.astype('category')

# %%
df.category.describe()
# Out:
# count     18
# unique    16
# top       27
# freq       2
# Name: <$10k, dtype: int64

# %%
df.category.cat.codes # 문자 데이터를 숫자 데이터로 만드는게 중요하다
# Out:
# A
# Agnostic                    9
# Atheist                     4
# Buddhist                    9
# Catholic                   14
# Don’t know/refused          6
# Evangelical Prot           15
# Hindu                       0
# Historically Black Prot    12
# Jehovah's Witness           8
# Jewish                      7
# Mainline Prot              13
# Mormon                     10
# Muslim                      2
# Orthodox                    5
# Other Christian             3
# Other Faiths                8
# Other World Religions       1
# Unaffiliated               11
# dtype: int8

# %%
# one - htot ecncoding
# label encoding

# %%
# astype('datetype')

# %%
# 데이터 읽기
# info
# 데이터 훓어보기 insight 찾기 
# astype으로 데이터 변경 
# 전처리란? -> 통계치 보고 agrigation하는디 전처리 겁나 하는거야
