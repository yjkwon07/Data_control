# %%
import pandas as pd

# %%
data = pd.read_csv("./data/pew.txt", delimiter="\t")

# %%
data
# Out:
#                    religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  \
# 0                  Agnostic     27       34       60       81       76
# 1                   Atheist     12       27       37       52       35
# 2                  Buddhist     27       21       30       34       33
# 3                  Catholic    418      617      732      670      638
# 4        Don’t know/refused     15       14       15       11       10
# 5          Evangelical Prot    575      869     1064      982      881
# 6                     Hindu      1        9        7        9       11
# 7   Historically Black Prot    228      244      236      238      197
# 8         Jehovah's Witness     20       27       24       24       21
# 9                    Jewish     19       19       25       25       30
# 10            Mainline Prot    289      495      619      655      651
# 11                   Mormon     29       40       48       51       56
# ...

# %%
data_long = pd.melt(data, id_vars= "religion") # id_vars 안바뀌는것 rename 이나 컬럼즈

# %%
data_long = pd.melt(data, id_vars="religion", var_name="income", value_name="count")

# %%
data_long.head()
# Out:
#              religion income  count
# 0            Agnostic  <$10k     27
# 1             Atheist  <$10k     12
# 2            Buddhist  <$10k     27
# 3            Catholic  <$10k    418
# 4  Don’t know/refused  <$10k     15

# %%
data.head()
# Out:
#              religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  $50-75k  \
# 0            Agnostic     27       34       60       81       76      137
# 1             Atheist     12       27       37       52       35       70
# 2            Buddhist     27       21       30       34       33       58
# 3            Catholic    418      617      732      670      638     1116
# 4  Don’t know/refused     15       14       15       11       10       35
#
#    $75-100k  $100-150k  >150k  Don't know/refused
# 0       122        109     84                  96
# 1        73         59     74                  76
# 2        62         39     53                  54
# 3       949        792    633                1489
# 4        21         17     18                 116

# %%
data.unstack()
# Out:
# religion            0                    Agnostic
#                     1                     Atheist
#                     2                    Buddhist
#                     3                    Catholic
#                     4          Don’t know/refused
#                     5            Evangelical Prot
#                     6                       Hindu
#                     7     Historically Black Prot
#                     8           Jehovah's Witness
#                     9                      Jewish
#                     10              Mainline Prot
#                     11                     Mormon
#                     12                     Muslim
#                     13                   Orthodox
#                     14            Other Christian
#                     15               Other Faiths
#                     16      Other World Religions
#                     17               Unaffiliated
# <$10k               0                          27
# ...

# %%
# object -> category -> 함수 통계 할 때 좋아
#        ->  str
# bool
# int64
# float64

# %%
data2 = pd.read_csv("./data/billboard_utf.csv", sep=",")

# %%
data2
# Out:
#      year                          artist.inverted  \
# 0    2000                          Destiny's Child
# 1    2000                                  Santana
# 2    2000                            Savage Garden
# 3    2000                                  Madonna
# 4    2000                      Aguilera, Christina
# 5    2000                                    Janet
# 6    2000                          Destiny's Child
# 7    2000                        Iglesias, Enrique
# 8    2000                                    Sisqo
# 9    2000                                 Lonestar
# 10   2000                                   N'Sync
# 11   2000                      Aguilera, Christina
# 12   2000                         Vertical Horizon
# 13   2000                                    Creed
# 14   2000                                  Aaliyah
# 15   2000                          matchbox twenty
# 16   2000                            Carey, Mariah
# ...

# %%
data2_long = pd.melt(data2, id_vars=["year", "artist.inverted", "track", "time", "genre"],
                    var_name="week", 
                    value_name="rating") 
# pd. -> 첫 번째 인자가 data frame # dataframe.melt -> 첫 번째 인자가 dataframe이 아니란 것

# %%
data2_long.head()
# Out:
#    year      artist.inverted                                  track  time  \
# 0  2000      Destiny's Child               Independent Women Part I  3:38
# 1  2000              Santana                           Maria, Maria  4:18
# 2  2000        Savage Garden                     I Knew I Loved You  4:07
# 3  2000              Madonna                                  Music  3:45
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
#
#   genre          week      rating
# 0  Rock  date.entered  2000-09-23
# 1  Rock  date.entered  2000-02-12
# 2  Rock  date.entered  1999-10-23
# 3  Rock  date.entered  2000-08-12
# 4  Rock  date.entered  2000-08-05

# %%
data2_long.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24726 entries, 0 to 24725
# Data columns (total 7 columns):
# year               24726 non-null int64
# artist.inverted    24726 non-null object
# track              24726 non-null object
# time               24726 non-null object
# genre              24726 non-null object
# week               24726 non-null object
# rating             5940 non-null object
# dtypes: int64(1), object(6)
# memory usage: 1.3+ MB

# %%
data2_long.week = data2_long.week.str.replace('week', '')

# %%
import numpy as np

# %%
data2_long.week = data2_long.week.str.replace('date.entered', np.nan)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-e9cb31f95b33> in <module>()
# ----> 1 data2_long.week = data2_long.week.str.replace('date.entered', np.nan)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\strings.py in replace(self, pat, repl, n, case, flags, regex)
#    2427     def replace(self, pat, repl, n=-1, case=None, flags=0, regex=True):
#    2428         result = str_replace(self._data, pat, repl, n=n, case=case,
# -> 2429                              flags=flags, regex=regex)
#    2430         return self._wrap_result(result)
#    2431
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\strings.py in str_replace(arr, pat, repl, n, case, flags, regex)
#     635     # Check whether repl is valid (GH 13438, GH 15055)
#     636     if not (is_string_like(repl) or callable(repl)):
# ...

# %%
data2_long.week = data2_long.week.str.replace('date.entered', '')

# %%
data2_long.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24726 entries, 0 to 24725
# Data columns (total 7 columns):
# year               24726 non-null int64
# artist.inverted    24726 non-null object
# track              24726 non-null object
# time               24726 non-null object
# genre              24726 non-null object
# week               24726 non-null object
# rating             5940 non-null object
# dtypes: int64(1), object(6)
# memory usage: 1.3+ MB

# %%
ebola = pd.read_csv("./data/country_timeseries.csv")

# %%
ebola # Cases_SierraLeone #국가 # case / country 따로?
# Out:
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289        2776.0            NaN            10030.0
# 1      1/4/2015  288        2775.0            NaN             9780.0
# 2      1/3/2015  287        2769.0         8166.0             9722.0
# 3      1/2/2015  286           NaN         8157.0                NaN
# 4    12/31/2014  284        2730.0         8115.0             9633.0
# 5    12/28/2014  281        2706.0         8018.0             9446.0
# 6    12/27/2014  280        2695.0            NaN             9409.0
# 7    12/24/2014  277        2630.0         7977.0             9203.0
# 8    12/21/2014  273        2597.0            NaN             9004.0
# 9    12/20/2014  272        2571.0         7862.0             8939.0
# 10   12/18/2014  271           NaN         7830.0                NaN
# 11   12/14/2014  267        2416.0            NaN             8356.0
# 12    12/9/2014  262           NaN         7797.0                NaN
# ...

# %%
ebola.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
# Date                   122 non-null object
# Day                    122 non-null int64
# Cases_Guinea           93 non-null float64
# Cases_Liberia          83 non-null float64
# Cases_SierraLeone      87 non-null float64
# Cases_Nigeria          38 non-null float64
# Cases_Senegal          25 non-null float64
# Cases_UnitedStates     18 non-null float64
# Cases_Spain            16 non-null float64
# Cases_Mali             12 non-null float64
# Deaths_Guinea          92 non-null float64
# Deaths_Liberia         81 non-null float64
# Deaths_SierraLeone     87 non-null float64
# Deaths_Nigeria         38 non-null float64
# Deaths_Senegal         22 non-null float64
# Deaths_UnitedStates    18 non-null float64
# Deaths_Spain           16 non-null float64
# Deaths_Mali            12 non-null float64
# dtypes: float64(16), int64(1), object(1)
# memory usage: 17.2+ KB

# %%
ebola.describe()
# Out:
#               Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# count  122.000000     93.000000      83.000000          87.000000
# mean   144.778689    911.064516    2335.337349        2427.367816
# std     89.316460    849.108801    2987.966721        3184.803996
# min      0.000000     49.000000       3.000000           0.000000
# 25%     66.250000    236.000000      25.500000          64.500000
# 50%    150.000000    495.000000     516.000000         783.000000
# 75%    219.500000   1519.000000    4162.500000        3801.000000
# max    289.000000   2776.000000    8166.000000       10030.000000
#
#        Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# count      38.000000          25.00           18.000000         16.0
# mean       16.736842           1.08            3.277778          1.0
# std         5.998577           0.40            1.178511          0.0
# min         0.000000           1.00            1.000000          1.0
# ...

# %%
ebola_long = pd.melt(ebola, id_vars= ['Date', 'Day'])
ebola_long .head()
# Out:
#          Date  Day      variable   value
# 0    1/5/2015  289  Cases_Guinea  2776.0
# 1    1/4/2015  288  Cases_Guinea  2775.0
# 2    1/3/2015  287  Cases_Guinea  2769.0
# 3    1/2/2015  286  Cases_Guinea     NaN
# 4  12/31/2014  284  Cases_Guinea  2730.0

# %%
"Cases_Guinea".split('_')
# Out:
# ['Cases', 'Guinea']

# %%
# string accessor
variable_split = ebola_long['variable'].str.split('_') # str -> string의 관한 함수를 쓰겠다. # ebola_long['variable'] <- sereise

# %%
type(variable_split)
# Out:
# pandas.core.series.Series

# %%
variable_split
# Out:
# 0       [Cases, Guinea]
# 1       [Cases, Guinea]
# 2       [Cases, Guinea]
# 3       [Cases, Guinea]
# 4       [Cases, Guinea]
# 5       [Cases, Guinea]
# 6       [Cases, Guinea]
# 7       [Cases, Guinea]
# 8       [Cases, Guinea]
# 9       [Cases, Guinea]
# 10      [Cases, Guinea]
# 11      [Cases, Guinea]
# 12      [Cases, Guinea]
# 13      [Cases, Guinea]
# 14      [Cases, Guinea]
# 15      [Cases, Guinea]
# 16      [Cases, Guinea]
# 17      [Cases, Guinea]
# 18      [Cases, Guinea]
# 19      [Cases, Guinea]
# 20      [Cases, Guinea]
# 21      [Cases, Guinea]
# 22      [Cases, Guinea]
# 23      [Cases, Guinea]
# 24      [Cases, Guinea]
# 25      [Cases, Guinea]
# 26      [Cases, Guinea]
# 27      [Cases, Guinea]
# 28      [Cases, Guinea]
# 29      [Cases, Guinea]
#              ...
# 1922     [Deaths, Mali]
# 1923     [Deaths, Mali]
# 1924     [Deaths, Mali]
# 1925     [Deaths, Mali]
# 1926     [Deaths, Mali]
# 1927     [Deaths, Mali]
# 1928     [Deaths, Mali]
# ...

# %%
type(variable_split[0])
# Out:
# list

# %%
variable_split[1951]
# Out:
# ['Deaths', 'Mali']

# %%
variable_split.get(0)
# Out:
# ['Cases', 'Guinea']

# %%
variable_split.str.get(0).head()
# Out:
# 0    Cases
# 1    Cases
# 2    Cases
# 3    Cases
# 4    Cases
# Name: variable, dtype: object

# %%
variable_split.str.get(1).head()
# Out:
# 0    Guinea
# 1    Guinea
# 2    Guinea
# 3    Guinea
# 4    Guinea
# Name: variable, dtype: object

# %%
status_values = variable_split[0]
status_values.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-84-5d9941da8a01> in <module>()
#       1 status_values = variable_split[0]
# ----> 2 status_values.head()
#
# AttributeError: 'list' object has no attribute 'head'

# %%
status_values = variable_split.get(0)
status_values.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-85-a5568adf585a> in <module>()
#       1 status_values = variable_split.get(0)
# ----> 2 status_values.head()
#
# AttributeError: 'list' object has no attribute 'head'

# %%
status_values = variable_split.str.get(1)
status_values.head()
# Out:
# 0    Guinea
# 1    Guinea
# 2    Guinea
# 3    Guinea
# 4    Guinea
# Name: variable, dtype: object

# %%
ebola_long['status'] = variable_split.str.get(0)
ebola_long['country'] = variable_split.str.get(1)

# %%
ebola_long[ebola_long.status=='Deaths'].groupby('country')[['value']].mean()
# Out:
#                     value
# country
# Guinea         563.239130
# Liberia       1101.209877
# Mali             3.166667
# Nigeria          6.131579
# Senegal          0.000000
# SierraLeone    693.701149
# Spain            0.187500
# UnitedStates     0.833333

# %%
ebola_long.dropna
# Out:
#             Date  Day      variable   value  status country
# 0       1/5/2015  289  Cases_Guinea  2776.0   Cases  Guinea
# 1       1/4/2015  288  Cases_Guinea  2775.0   Cases  Guinea
# 2       1/3/2015  287  Cases_Guinea  2769.0   Cases  Guinea
# 3       1/2/2015  286  Cases_Guinea     NaN   Cases  Guinea
# 4     12/31/2014  284  Cases_Guinea  2730.0   Cases  Guinea
# 5     12/28/2014  281  Cases_Guinea  2706.0   Cases  Guinea
# 6     12/27/2014  280  Cases_Guinea  2695.0   Cases  Guinea
# 7     12/24/2014  277  Cases_Guinea  2630.0   Cases  Guinea
# 8     12/21/2014  273  Cases_Guinea  2597.0   Cases  Guinea
# 9     12/20/2014  272  Cases_Guinea  2571.0   Cases  Guinea
# 10    12/18/2014  271  Cases_Guinea     NaN   Cases  Guinea
# 11    12/14/2014  267  Cases_Guinea  2416.0   Cases  Guinea
# 12     12/9/2014  262  Cases_Guinea     NaN   Cases  Guinea
# 13     12/7/2014  260  Cases_Guinea  2292.0   Cases  Guinea
# 14     12/3/2014  256  Cases_Guinea     NaN   Cases  Guinea
# ...

# %%
weather = pd.read_csv('./data/weather.txt', delimiter='\t')

# %%
weather # day , nan -> dropna
# Out:
#              id  year  month element     d1     d2     d3     d4     d5  \
# 0   MX000017004  2010      1    TMAX    NaN    NaN    NaN    NaN    NaN
# 1   MX000017004  2010      1    TMIN    NaN    NaN    NaN    NaN    NaN
# 2   MX000017004  2010      2    TMAX    NaN  273.0  241.0    NaN    NaN
# 3   MX000017004  2010      2    TMIN    NaN  144.0  144.0    NaN    NaN
# 4   MX000017004  2010      3    TMAX    NaN    NaN    NaN    NaN  321.0
# 5   MX000017004  2010      3    TMIN    NaN    NaN    NaN    NaN  142.0
# 6   MX000017004  2010      4    TMAX    NaN    NaN    NaN    NaN    NaN
# 7   MX000017004  2010      4    TMIN    NaN    NaN    NaN    NaN    NaN
# 8   MX000017004  2010      5    TMAX    NaN    NaN    NaN    NaN    NaN
# 9   MX000017004  2010      5    TMIN    NaN    NaN    NaN    NaN    NaN
# 10  MX000017004  2010      6    TMAX    NaN    NaN    NaN    NaN    NaN
# 11  MX000017004  2010      6    TMIN    NaN    NaN    NaN    NaN    NaN
# ...

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 35 columns):
# id         22 non-null object
# year       22 non-null int64
# month      22 non-null int64
# element    22 non-null object
# d1         2 non-null float64
# d2         4 non-null float64
# d3         4 non-null float64
# d4         2 non-null float64
# d5         8 non-null float64
# d6         2 non-null float64
# d7         2 non-null float64
# d8         2 non-null float64
# d9         0 non-null float64
# d10        2 non-null float64
# d11        2 non-null float64
# d12        0 non-null float64
# d13        2 non-null float64
# d14        4 non-null float64
# d15        2 non-null float64
# d16        2 non-null float64
# d17        2 non-null float64
# d18        0 non-null float64
# d19        0 non-null float64
# d20        0 non-null float64
# d21        0 non-null float64
# d22        0 non-null float64
# d23        4 non-null float64
# ...

# %%
weather_long = pd.melt(weather, id_vars=["id","year","month","element"],
                    var_name="day", 
                    value_name="temp")

# %%
weather_long
# Out:
#               id  year  month element  day   temp
# 0    MX000017004  2010      1    TMAX   d1    NaN
# 1    MX000017004  2010      1    TMIN   d1    NaN
# 2    MX000017004  2010      2    TMAX   d1    NaN
# 3    MX000017004  2010      2    TMIN   d1    NaN
# 4    MX000017004  2010      3    TMAX   d1    NaN
# 5    MX000017004  2010      3    TMIN   d1    NaN
# 6    MX000017004  2010      4    TMAX   d1    NaN
# 7    MX000017004  2010      4    TMIN   d1    NaN
# 8    MX000017004  2010      5    TMAX   d1    NaN
# 9    MX000017004  2010      5    TMIN   d1    NaN
# 10   MX000017004  2010      6    TMAX   d1    NaN
# 11   MX000017004  2010      6    TMIN   d1    NaN
# 12   MX000017004  2010      7    TMAX   d1    NaN
# 13   MX000017004  2010      7    TMIN   d1    NaN
# 14   MX000017004  2010      8    TMAX   d1    NaN
# 15   MX000017004  2010      8    TMIN   d1    NaN
# 16   MX000017004  2010     10    TMAX   d1    NaN
# 17   MX000017004  2010     10    TMIN   d1    NaN
# ...

# %%
weather_long.dropna(inplace=True)

# %%
weather_long[weather_long.day == "d1"]
# Out:
#              id  year  month element day   temp
# 20  MX000017004  2010     12    TMAX  d1  299.0
# 21  MX000017004  2010     12    TMIN  d1  138.0

# %%
weather_long.pivot_table(index=["id","year","month","day"],columns="element",values="temp").reset_index()
# Out:
# element           id  year  month  day   TMAX   TMIN
# 0        MX000017004  2010      1  d30  278.0  145.0
# 1        MX000017004  2010      2  d11  297.0  134.0
# 2        MX000017004  2010      2   d2  273.0  144.0
# 3        MX000017004  2010      2  d23  299.0  107.0
# 4        MX000017004  2010      2   d3  241.0  144.0
# 5        MX000017004  2010      3  d10  345.0  168.0
# 6        MX000017004  2010      3  d16  311.0  176.0
# 7        MX000017004  2010      3   d5  321.0  142.0
# 8        MX000017004  2010      4  d27  363.0  167.0
# 9        MX000017004  2010      5  d27  332.0  182.0
# 10       MX000017004  2010      6  d17  280.0  175.0
# 11       MX000017004  2010      6  d29  301.0  180.0
# 12       MX000017004  2010      7  d14  299.0  165.0
# 13       MX000017004  2010      7   d3  286.0  175.0
# 14       MX000017004  2010      8  d13  298.0  165.0
# 15       MX000017004  2010      8  d23  264.0  150.0
# 16       MX000017004  2010      8  d25  297.0  156.0
# ...

# %%
weather_long_pivot = (weather_long.pivot_table(index=["id","year","month","day"],columns="element",values="temp").reset_index() )

# %%
weather_long_pivot[weather_long_pivot.day == 'd1']
# Out:
# element           id  year  month day   TMAX   TMIN
# 31       MX000017004  2010     12  d1  299.0  138.0

# %%
weather_long.reset_index()
# Out:
# element           id  year  month  day   TMAX   TMIN
# 0        MX000017004  2010      1  d30  278.0  145.0
# 1        MX000017004  2010      2  d11  297.0  134.0
# 2        MX000017004  2010      2   d2  273.0  144.0
# 3        MX000017004  2010      2  d23  299.0  107.0
# 4        MX000017004  2010      2   d3  241.0  144.0
# 5        MX000017004  2010      3  d10  345.0  168.0
# 6        MX000017004  2010      3  d16  311.0  176.0
# 7        MX000017004  2010      3   d5  321.0  142.0
# 8        MX000017004  2010      4  d27  363.0  167.0
# 9        MX000017004  2010      5  d27  332.0  182.0
# 10       MX000017004  2010      6  d17  280.0  175.0
# 11       MX000017004  2010      6  d29  301.0  180.0
# 12       MX000017004  2010      7  d14  299.0  165.0
# 13       MX000017004  2010      7   d3  286.0  175.0
# 14       MX000017004  2010      8  d13  298.0  165.0
# 15       MX000017004  2010      8  d23  264.0  150.0
# 16       MX000017004  2010      8  d25  297.0  156.0
# ...

# %%
billboard = pd.read_csv("./data/billboard.csv", engine='python')

# %%
billboard
# Out:
#      year      artist.inverted  \
# 0    2000      Destiny's Child
# 1    2000              Santana
# 2    2000        Savage Garden
# 3    2000              Madonna
# 4    2000  Aguilera, Christina
# 5    2000                Janet
# 6    2000      Destiny's Child
# 7    2000    Iglesias, Enrique
# 8    2000                Sisqo
# 9    2000             Lonestar
# 10   2000               N'Sync
# 11   2000  Aguilera, Christina
# 12   2000     Vertical Horizon
# 13   2000                Creed
# 14   2000              Aaliyah
# 15   2000      matchbox twenty
# 16   2000        Carey, Mariah
# 17   2000          Hill, Faith
# 18   2000                  Mya
# 19   2000                Dream
# 20   2000        Braxton, Toni
# 21   2000        Anthony, Marc
# 22   2000                  98�
# 23   2000      Destiny's Child
# 24   2000         3 Doors Down
# 25   2000                Sisqo
# 26   2000  Aguilera, Christina
# 27   2000     Houston, Whitney
# 28   2000                  Joe
# ...

# %%
billboard.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 317 entries, 0 to 316
# Data columns (total 83 columns):
# year               317 non-null int64
# artist.inverted    317 non-null object
# track              317 non-null object
# time               317 non-null object
# genre              317 non-null object
# date.entered       317 non-null object
# date.peaked        317 non-null object
# x1st.week          317 non-null int64
# x2nd.week          312 non-null float64
# x3rd.week          307 non-null float64
# x4th.week          300 non-null float64
# x5th.week          292 non-null float64
# x6th.week          280 non-null float64
# x7th.week          269 non-null float64
# x8th.week          260 non-null float64
# x9th.week          253 non-null float64
# x10th.week         244 non-null float64
# x11th.week         236 non-null float64
# x12th.week         222 non-null float64
# x13th.week         210 non-null float64
# x14th.week         204 non-null float64
# ...

# %%
billboard.describe()
# Out:
#          year   x1st.week   x2nd.week   x3rd.week   x4th.week   x5th.week  \
# count   317.0  317.000000  312.000000  307.000000  300.000000  292.000000
# mean   2000.0   79.958991   71.173077   65.045603   59.763333   56.339041
# std       0.0   14.686865   18.200443   20.752302   22.324619   23.780022
# min    2000.0   15.000000    8.000000    6.000000    5.000000    2.000000
# 25%    2000.0   74.000000   63.000000   53.000000   44.750000   38.750000
# 50%    2000.0   81.000000   73.000000   66.000000   61.000000   57.000000
# 75%    2000.0   91.000000   84.000000   79.000000   76.000000   73.250000
# max    2000.0  100.000000  100.000000  100.000000  100.000000  100.000000
#
#         x6th.week   x7th.week   x8th.week   x9th.week     ...      x67th.week  \
# count  280.000000  269.000000  260.000000  253.000000     ...             0.0
# mean    52.360714   49.219331   47.119231   46.343874     ...             NaN
# ...

# %%
billboard_long = pd.melt(billboard, id_vars=["year","artist.inverted", "track", "time","genre","date.entered","date.peaked"],
                   var_name="week",
                        value_name="rating")

# %%
billboard_long
# Out:
#        year      artist.inverted  \
# 0      2000      Destiny's Child
# 1      2000              Santana
# 2      2000        Savage Garden
# 3      2000              Madonna
# 4      2000  Aguilera, Christina
# 5      2000                Janet
# 6      2000      Destiny's Child
# 7      2000    Iglesias, Enrique
# 8      2000                Sisqo
# 9      2000             Lonestar
# 10     2000               N'Sync
# 11     2000  Aguilera, Christina
# 12     2000     Vertical Horizon
# 13     2000                Creed
# 14     2000              Aaliyah
# 15     2000      matchbox twenty
# 16     2000        Carey, Mariah
# 17     2000          Hill, Faith
# 18     2000                  Mya
# 19     2000                Dream
# 20     2000        Braxton, Toni
# 21     2000        Anthony, Marc
# 22     2000                  98�
# 23     2000      Destiny's Child
# 24     2000         3 Doors Down
# 25     2000                Sisqo
# 26     2000  Aguilera, Christina
# ...

# %%
billboard_long.dropna(inplace=True)

# %%
billboard_long
# Out:
#        year      artist.inverted                                  track  time  \
# 0      2000      Destiny's Child               Independent Women Part I  3:38
# 1      2000              Santana                           Maria, Maria  4:18
# 2      2000        Savage Garden                     I Knew I Loved You  4:07
# 3      2000              Madonna                                  Music  3:45
# 4      2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
# 5      2000                Janet                  Doesn't Really Matter  4:17
# 6      2000      Destiny's Child                            Say My Name  4:31
# 7      2000    Iglesias, Enrique                            Be With You  3:36
# 8      2000                Sisqo                             Incomplete  3:52
# 9      2000             Lonestar                                 Amazed  4:25
# 10     2000               N'Sync                       It's Gonna Be Me  3:10
# ...

# %%
billboard_long.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5307 entries, 0 to 20334
# Data columns (total 9 columns):
# year               5307 non-null int64
# artist.inverted    5307 non-null object
# track              5307 non-null object
# time               5307 non-null object
# genre              5307 non-null object
# date.entered       5307 non-null object
# date.peaked        5307 non-null object
# week               5307 non-null object
# rating             5307 non-null float64
# dtypes: float64(1), int64(1), object(7)
# memory usage: 414.6+ KB

# %%
billboard_long.describe()
# Out:
#          year       rating
# count  5307.0  5307.000000
# mean   2000.0    51.052384
# std       0.0    28.966198
# min    2000.0     1.000000
# 25%    2000.0    26.000000
# 50%    2000.0    51.000000
# 75%    2000.0    76.000000
# max    2000.0   100.000000

# %%
billboard_long.head()
# Out:
#    year      artist.inverted                                  track  time  \
# 0  2000      Destiny's Child               Independent Women Part I  3:38
# 1  2000              Santana                           Maria, Maria  4:18
# 2  2000        Savage Garden                     I Knew I Loved You  4:07
# 3  2000              Madonna                                  Music  3:45
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
#
#   genre date.entered date.peaked       week  rating
# 0  Rock   2000-09-23  2000-11-18  x1st.week    78.0
# 1  Rock   2000-02-12  2000-04-08  x1st.week    15.0
# 2  Rock   1999-10-23  2000-01-29  x1st.week    71.0
# 3  Rock   2000-08-12  2000-09-16  x1st.week    41.0
# 4  Rock   2000-08-05  2000-10-14  x1st.week    57.0

# %%
billboard_long.nsmallest(5, 'year')
# Out:
#    year      artist.inverted                                  track  time  \
# 0  2000      Destiny's Child               Independent Women Part I  3:38
# 1  2000              Santana                           Maria, Maria  4:18
# 2  2000        Savage Garden                     I Knew I Loved You  4:07
# 3  2000              Madonna                                  Music  3:45
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
#
#   genre date.entered date.peaked       week  rating
# 0  Rock   2000-09-23  2000-11-18  x1st.week    78.0
# 1  Rock   2000-02-12  2000-04-08  x1st.week    15.0
# 2  Rock   1999-10-23  2000-01-29  x1st.week    71.0
# 3  Rock   2000-08-12  2000-09-16  x1st.week    41.0
# 4  Rock   2000-08-05  2000-10-14  x1st.week    57.0

# %%
# 시간 날짜, 위치정보  
# timeseries 시계열  -> 조금 영역이 달라 
# 별도의 분야로 다루기도 한다. -> 사이킷에서도 온전하게 다룰 수 없다. 
# 시계열은 날짜와 시간 
# 날짜와 시간은 파이썬에서 기본적인 데이터 구조가 없다. 
# import를 해야한다. 
# 표준라이브러리가 있지만, 기본적인 데이터구조가 없다. 
# 표준라이브러리에는 총 3가지가 있다.
# 시계열은 3가지의 라이브러리를 알아야한다. 
# time, 
# 치명적인 단점; 시간 관련된 라이브러리를 잘 안만들어서
# dateutil로 서브로 지원을 받아야한다.  <- 쉽게 사용할 수 있따.
# pytz <- python time지원이 별로라 만들어놈 
# https://pendulum.eustace.io/ <- 요즘 나온 기술  
#

# %%
temp_data = pd.to_datetime(billboard_long['date.entered'])

# %%
temp_data
# Out:
# 0       2000-09-23
# 1       2000-02-12
# 2       1999-10-23
# 3       2000-08-12
# 4       2000-08-05
# 5       2000-06-17
# 6       1999-12-25
# 7       2000-04-01
# 8       2000-06-24
# 9       1999-06-05
# 10      2000-05-06
# 11      1999-11-27
# 12      2000-01-22
# 13      2000-05-13
# 14      2000-03-18
# 15      2000-04-29
# 16      1999-12-11
# 17      1999-11-06
# 18      2000-08-19
# 19      2000-09-30
# 20      2000-03-18
# 21      2000-02-26
# 22      2000-08-19
# 23      2000-05-13
# 24      2000-04-08
# 25      2000-01-29
# 26      2000-04-15
# 27      1999-09-04
# 28      2000-01-01
# 29      1999-10-23
#            ...
# 16184   1999-11-06
# 16191   2000-04-08
# 16213   1999-09-11
# 16493   1999-06-05
# 16501   1999-11-06
# 16508   2000-04-08
# 16530   1999-09-11
# 16810   1999-06-05
# 16847   1999-09-11
# 17127   1999-06-05
# 17164   1999-09-11
# 17444   1999-06-05
# 17481   1999-09-11
# 17761   1999-06-05
# 17798   1999-09-11
# 18078   1999-06-05
# ...

# %%
billboard_long['date.entered'] = temp_data

# %%
billboard_long
# Out:
#        year      artist.inverted                                  track  time  \
# 0      2000      Destiny's Child               Independent Women Part I  3:38
# 1      2000              Santana                           Maria, Maria  4:18
# 2      2000        Savage Garden                     I Knew I Loved You  4:07
# 3      2000              Madonna                                  Music  3:45
# 4      2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
# 5      2000                Janet                  Doesn't Really Matter  4:17
# 6      2000      Destiny's Child                            Say My Name  4:31
# 7      2000    Iglesias, Enrique                            Be With You  3:36
# 8      2000                Sisqo                             Incomplete  3:52
# 9      2000             Lonestar                                 Amazed  4:25
# 10     2000               N'Sync                       It's Gonna Be Me  3:10
# ...

# %%
billboard_long.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5307 entries, 0 to 20334
# Data columns (total 9 columns):
# year               5307 non-null int64
# artist.inverted    5307 non-null object
# track              5307 non-null object
# time               5307 non-null object
# genre              5307 non-null object
# date.entered       5307 non-null datetime64[ns]
# date.peaked        5307 non-null object
# week               5307 non-null object
# rating             5307 non-null float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(6)
# memory usage: 414.6+ KB

# %%
billboard_long['date.entered']['2010'] # 인덱스가 안됨 값으로 들어갔기 때문에  # 인덱스가 시계열로 들어가야한다.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-160-1b811cf1ae21> in <module>()
# ----> 1 billboard_long['date.entered']['2010'] # 인덱스가 안됨 값으로 들어갔기 때문에
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     765         key = com._apply_if_callable(key, self)
#     766         try:
# --> 767             result = self.index.get_value(self, key)
#     768
#     769             if not is_scalar(result):
#
# ...
