# %%
import pandas as pd
df = pd.read_csv('./data/data-zillow.csv', sep=',', engine='python')

# %%
df.info()  # object 대부분 string
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10830 entries, 0 to 10829
# Data columns (total 8 columns):
# Date          10830 non-null object
# RegionID      10830 non-null int64
# RegionName    10830 non-null object
# State         10830 non-null object
# Metro         10256 non-null object
# County        10830 non-null object
# SizeRank      10830 non-null int64
# Zhvi          10830 non-null int64
# dtypes: int64(3), object(5)
# memory usage: 677.0+ KB

# %%
df.RegionName.str.capitalize
# help function 지원(자동완성) bound method _noarg_wrapper. -> () 
# 단점 공백있을 때 사용 못함
# Out:
# <bound method _noarg_wrapper.<locals>.wrapper of <pandas.core.strings.StringMethods object at 0x00000156BFE14EF0>>

# %%
df.RegionName.str.capitalize()
# Out:
# 0                 New york
# 1              Los angeles
# 2                  Chicago
# 3             Philadelphia
# 4                  Phoenix
# 5                Las vegas
# 6                San diego
# 7                   Dallas
# 8                 San jose
# 9             Jacksonville
# 10           San francisco
# 11                  Austin
# 12                 Detroit
# 13                Columbus
# 14                 Memphis
# 15               Charlotte
# 16                 El paso
# 17                  Boston
# 18                 Seattle
# 19               Baltimore
# 20                  Denver
# 21              Washington
# 22               Nashville
# 23               Milwaukee
# 24                  Tucson
# 25                Portland
# 26           Oklahoma city
# 27                   Omaha
# 28             Albuquerque
# 29                  Fresno
#                ...
# 10800         Mount sidney
# 10801          Cedar grove
# 10802                Clark
# ...

# %%
df['RegionName'].str.upper() 
#help function 지원x 그래서 어트리뷰트 방식 많이 사용
# Out:
# 0                 NEW YORK
# 1              LOS ANGELES
# 2                  CHICAGO
# 3             PHILADELPHIA
# 4                  PHOENIX
# 5                LAS VEGAS
# 6                SAN DIEGO
# 7                   DALLAS
# 8                 SAN JOSE
# 9             JACKSONVILLE
# 10           SAN FRANCISCO
# 11                  AUSTIN
# 12                 DETROIT
# 13                COLUMBUS
# 14                 MEMPHIS
# 15               CHARLOTTE
# 16                 EL PASO
# 17                  BOSTON
# 18                 SEATTLE
# 19               BALTIMORE
# 20                  DENVER
# 21              WASHINGTON
# 22               NASHVILLE
# 23               MILWAUKEE
# 24                  TUCSON
# 25                PORTLAND
# 26           OKLAHOMA CITY
# 27                   OMAHA
# 28             ALBUQUERQUE
# 29                  FRESNO
#                ...
# 10800         MOUNT SIDNEY
# 10801          CEDAR GROVE
# 10802                CLARK
# ...

# %%
df['RegionName'] = df.RegionName.str.upper() # upper함수로 전체 다 바꿈

# %%
df.RegionName.str.replace('YORK', 'york')
# Out:
# 0                 NEW york
# 1              LOS ANGELES
# 2                  CHICAGO
# 3             PHILADELPHIA
# 4                  PHOENIX
# 5                LAS VEGAS
# 6                SAN DIEGO
# 7                   DALLAS
# 8                 SAN JOSE
# 9             JACKSONVILLE
# 10           SAN FRANCISCO
# 11                  AUSTIN
# 12                 DETROIT
# 13                COLUMBUS
# 14                 MEMPHIS
# 15               CHARLOTTE
# 16                 EL PASO
# 17                  BOSTON
# 18                 SEATTLE
# 19               BALTIMORE
# 20                  DENVER
# 21              WASHINGTON
# 22               NASHVILLE
# 23               MILWAUKEE
# 24                  TUCSON
# 25                PORTLAND
# 26           OKLAHOMA CITY
# 27                   OMAHA
# 28             ALBUQUERQUE
# 29                  FRESNO
#                ...
# 10800         MOUNT SIDNEY
# 10801          CEDAR GROVE
# 10802                CLARK
# ...

# %%
df.RegionName.map(lambda x : x + '문근영') 
#str은 컬럼 전체 다 바꿔줌 함수형 기법으로 만든 것
# Out:
# 0                 NEW YORK문근영
# 1              LOS ANGELES문근영
# 2                  CHICAGO문근영
# 3             PHILADELPHIA문근영
# 4                  PHOENIX문근영
# 5                LAS VEGAS문근영
# 6                SAN DIEGO문근영
# 7                   DALLAS문근영
# 8                 SAN JOSE문근영
# 9             JACKSONVILLE문근영
# 10           SAN FRANCISCO문근영
# 11                  AUSTIN문근영
# 12                 DETROIT문근영
# 13                COLUMBUS문근영
# 14                 MEMPHIS문근영
# 15               CHARLOTTE문근영
# 16                 EL PASO문근영
# 17                  BOSTON문근영
# 18                 SEATTLE문근영
# 19               BALTIMORE문근영
# 20                  DENVER문근영
# 21              WASHINGTON문근영
# 22               NASHVILLE문근영
# 23               MILWAUKEE문근영
# 24                  TUCSON문근영
# 25                PORTLAND문근영
# 26           OKLAHOMA CITY문근영
# 27                   OMAHA문근영
# 28             ALBUQUERQUE문근영
# 29                  FRESNO문근영
#                  ...
# ...

# %%
df.RegionID.map(lambda x : str(x).format('.8%d'))
# Out:
# 0          6181
# 1         12447
# 2         17426
# 3         13271
# 4         40326
# 5         18959
# 6         54296
# 7         38128
# 8         33839
# 9         25290
# 10        20330
# 11        10221
# 12        17762
# 13        10920
# 14        32811
# 15        24043
# 16        17933
# 17        44269
# 18        16037
# 19         3523
# 20        11093
# 21        41568
# 22         6118
# 23         5976
# 24         7481
# 25        13373
# 26        33225
# 27        40152
# 28        23429
# 29        18203
#           ...
# 10800     36944
# 10801     44501
# 10802     44615
# 10803     44844
# 10804     49693
# 10805     50692
# 10806    171874
# 10807      7512
# 10808      8646
# 10809     13137
# 10810     25468
# 10811     25749
# 10812     25835
# 10813     32017
# 10814     32847
# 10815     46172
# 10816     46452
# 10817     49856
# 10818     54802
# 10819     55357
# 10820      5216
# 10821     12312
# 10822     18317
# 10823     19929
# ...

# %%
df.County.str.lower()
# Out:
# 0                      queens
# 1                 los angeles
# 2                        cook
# 3                philadelphia
# 4                    maricopa
# 5                       clark
# 6                   san diego
# 7                      dallas
# 8                 santa clara
# 9                       duval
# 10              san francisco
# 11                     travis
# 12                      wayne
# 13                   franklin
# 14                     shelby
# 15                mecklenburg
# 16                    el paso
# 17                    suffolk
# 18                       king
# 19             baltimore city
# 20                     denver
# 21       district of columbia
# 22                   davidson
# 23                  milwaukee
# 24                       pima
# 25                  multnomah
# 26                   oklahoma
# 27                    douglas
# 28                 bernalillo
# 29                     fresno
#                  ...
# ...

# %%
df['문근영'] = df.County.str.len()

# %%
df
# Out:
#              Date  RegionID         RegionName State  \
# 0      2017-05-31      6181           NEW YORK    NY
# 1      2017-05-31     12447        LOS ANGELES    CA
# 2      2017-05-31     17426            CHICAGO    IL
# 3      2017-05-31     13271       PHILADELPHIA    PA
# 4      2017-05-31     40326            PHOENIX    AZ
# 5      2017-05-31     18959          LAS VEGAS    NV
# 6      2017-05-31     54296          SAN DIEGO    CA
# 7      2017-05-31     38128             DALLAS    TX
# 8      2017-05-31     33839           SAN JOSE    CA
# 9      2017-05-31     25290       JACKSONVILLE    FL
# 10     2017-05-31     20330      SAN FRANCISCO    CA
# 11     2017-05-31     10221             AUSTIN    TX
# 12     2017-05-31     17762            DETROIT    MI
# 13     2017-05-31     10920           COLUMBUS    OH
# 14     2017-05-31     32811            MEMPHIS    TN
# 15     2017-05-31     24043          CHARLOTTE    NC
# 16     2017-05-31     17933            EL PASO    TX
# ...

# %%
df.RegionName.str.replace('', "")
# Out:
# 0                 NEW YORK
# 1              LOS ANGELES
# 2                  CHICAGO
# 3             PHILADELPHIA
# 4                  PHOENIX
# 5                LAS VEGAS
# 6                SAN DIEGO
# 7                   DALLAS
# 8                 SAN JOSE
# 9             JACKSONVILLE
# 10           SAN FRANCISCO
# 11                  AUSTIN
# 12                 DETROIT
# 13                COLUMBUS
# 14                 MEMPHIS
# 15               CHARLOTTE
# 16                 EL PASO
# 17                  BOSTON
# 18                 SEATTLE
# 19               BALTIMORE
# 20                  DENVER
# 21              WASHINGTON
# 22               NASHVILLE
# 23               MILWAUKEE
# 24                  TUCSON
# 25                PORTLAND
# 26           OKLAHOMA CITY
# 27                   OMAHA
# 28             ALBUQUERQUE
# 29                  FRESNO
#                ...
# 10800         MOUNT SIDNEY
# 10801          CEDAR GROVE
# 10802                CLARK
# ...
