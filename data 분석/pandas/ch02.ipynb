# %%
import pandas as pd
df = pd.read_csv("data-netflix.csv", engine='python')

# %%
df
# Out:
#                                           title rating  \
# 0                                  White Chicks  PG-13
# 1                           Lucky Number Slevin      R
# 2                                Grey's Anatomy  TV-14
# 3                                  Prison Break  TV-14
# 4                         How I Met Your Mother  TV-PG
# 5                                  Supernatural  TV-14
# 6                                  Breaking Bad  TV-MA
# 7                           The Vampire Diaries  TV-14
# 8                              The Walking Dead  TV-MA
# 9                           Pretty Little Liars  TV-14
# 10                             Once Upon a Time  TV-PG
# 11                                     Sherlock  TV-14
# 12                                   Death Note  TV-14
# 13                                       Naruto  TV-PG
# 14                                   The Hunter      R
# 15                        Lottie Dottie Chicken   TV-Y
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
# title                1000 non-null object
# rating               1000 non-null object
# ratingLevel          941 non-null object
# ratingDescription    1000 non-null int64
# release year         1000 non-null int64
# user rating score    605 non-null float64
# user rating size     1000 non-null int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 54.8+ KB

# %%
df.describe()
# Out:
#        ratingDescription  release year  user rating score  user rating size
# count         1000.00000   1000.000000         605.000000       1000.000000
# mean            67.36600   2010.335000          84.094215         80.783000
# std             30.78561      8.877927          12.344371          0.973066
# min             10.00000   1940.000000          55.000000         80.000000
# 25%             35.00000   2007.000000          75.000000         80.000000
# 50%             60.00000   2015.000000          88.000000         80.000000
# 75%             90.00000   2016.000000          95.000000         82.000000
# max            124.00000   2017.000000          99.000000         82.000000

# %%
df.sample()
# Out:
#        title rating                                        ratingLevel  \
# 11  Sherlock  TV-14  Parents strongly cautioned. May be unsuitable ...
#
#     ratingDescription  release year  user rating score  user rating size
# 11                 90          2016               95.0                80

# %%
df.head()
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
#
#    release year  user rating score  user rating size
# 0          2004               82.0                80
# 1          2006                NaN                82
# 2          2016               98.0                80
# 3          2008               98.0                80
# 4          2014               94.0                80

# %%
df['title']
# Out:
# 0                                    White Chicks
# 1                             Lucky Number Slevin
# 2                                  Grey's Anatomy
# 3                                    Prison Break
# 4                           How I Met Your Mother
# 5                                    Supernatural
# 6                                    Breaking Bad
# 7                             The Vampire Diaries
# 8                                The Walking Dead
# 9                             Pretty Little Liars
# 10                               Once Upon a Time
# 11                                       Sherlock
# 12                                     Death Note
# 13                                         Naruto
# 14                                     The Hunter
# 15                          Lottie Dottie Chicken
# 16                                          Arrow
# 17                                   Black Mirror
# 18                                  The Originals
# ...

# %%
type(df['title']) #가장 많이 씀
# Out:
# pandas.core.series.Series

# %%
df.title 
#컬럼 하나 가져오고 싶을 때, dict 방식, attribute 방식(dot notataiton) 
#-> .name이기 때문에 두 개이상 못 뽑아
# Out:
# 0                                    White Chicks
# 1                             Lucky Number Slevin
# 2                                  Grey's Anatomy
# 3                                    Prison Break
# 4                           How I Met Your Mother
# 5                                    Supernatural
# 6                                    Breaking Bad
# 7                             The Vampire Diaries
# 8                                The Walking Dead
# 9                             Pretty Little Liars
# 10                               Once Upon a Time
# 11                                       Sherlock
# 12                                     Death Note
# 13                                         Naruto
# 14                                     The Hunter
# 15                          Lottie Dottie Chicken
# 16                                          Arrow
# 17                                   Black Mirror
# 18                                  The Originals
# ...

# %%
df[['title','rating']] # 컬럼 전체를 뽑는 것
# Out:
#                                           title rating
# 0                                  White Chicks  PG-13
# 1                           Lucky Number Slevin      R
# 2                                Grey's Anatomy  TV-14
# 3                                  Prison Break  TV-14
# 4                         How I Met Your Mother  TV-PG
# 5                                  Supernatural  TV-14
# 6                                  Breaking Bad  TV-MA
# 7                           The Vampire Diaries  TV-14
# 8                              The Walking Dead  TV-MA
# 9                           Pretty Little Liars  TV-14
# 10                             Once Upon a Time  TV-PG
# 11                                     Sherlock  TV-14
# 12                                   Death Note  TV-14
# 13                                       Naruto  TV-PG
# 14                                   The Hunter      R
# 15                        Lottie Dottie Chicken   TV-Y
# ...

# %%
df[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-ad11118bc8f3> in <module>()
# ----> 1 df[0]
#
# ...

# %%
df.loc[0] #row
# Out:
# title                                                     White Chicks
# rating                                                           PG-13
# ratingLevel          crude and sexual humor, language and some drug...
# ratingDescription                                                   80
# release year                                                      2004
# user rating score                                                   82
# user rating size                                                    80
# Name: 0, dtype: object

# %%
df.loc[0,1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-2f541e4c5994> in <module>()
# ----> 1 df.loc[0,1]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1470             except (KeyError, IndexError):
#    1471                 pass
# -> 1472             return self._getitem_tuple(key)
#    1473         else:
#    1474             # we by definition only have the 0th axis
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     868     def _getitem_tuple(self, tup):
#     869         try:
# --> 870             return self._getitem_lowerdim(tup)
#     871         except IndexingError:
#     872             pass
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
#    1025                     return section
# ...

# %%
df.loc[[0,1]] 
# 판다스에서는 리스트형태로 인자로 넣으면 동시에 나온다.  
# index 방식 -> 파이썬에서는 동시에여러개 가져오는거 지원하지 않지만 판다스는 가능하게 만듬
# Out:
#                  title rating  \
# 0         White Chicks  PG-13
# 1  Lucky Number Slevin      R
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
#
#    release year  user rating score  user rating size
# 0          2004               82.0                80
# 1          2006                NaN                82

# %%
df.loc[1:3] #슬라이싱
# Out:
#                  title rating  \
# 1  Lucky Number Slevin      R
# 2       Grey's Anatomy  TV-14
# 3         Prison Break  TV-14
#
#                                          ratingLevel  ratingDescription  \
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
#
#    release year  user rating score  user rating size
# 1          2006                NaN                82
# 2          2016               98.0                80
# 3          2008               98.0                80

# %%
df.loc[1:3,'title']
# Out:
# 1    Lucky Number Slevin
# 2         Grey's Anatomy
# 3           Prison Break
# Name: title, dtype: object

# %%
df.loc[1:3, ['title','rating']]
# Out:
#                  title rating
# 1  Lucky Number Slevin      R
# 2       Grey's Anatomy  TV-14
# 3         Prison Break  TV-14

# %%
df.loc[:, ['title','rating']] #전체 가져오기, dict방식  똑같아짐
# Out:
#                                           title rating
# 0                                  White Chicks  PG-13
# 1                           Lucky Number Slevin      R
# 2                                Grey's Anatomy  TV-14
# 3                                  Prison Break  TV-14
# 4                         How I Met Your Mother  TV-PG
# 5                                  Supernatural  TV-14
# 6                                  Breaking Bad  TV-MA
# 7                           The Vampire Diaries  TV-14
# 8                              The Walking Dead  TV-MA
# 9                           Pretty Little Liars  TV-14
# 10                             Once Upon a Time  TV-PG
# 11                                     Sherlock  TV-14
# 12                                   Death Note  TV-14
# 13                                       Naruto  TV-PG
# 14                                   The Hunter      R
# 15                        Lottie Dottie Chicken   TV-Y
# ...

# %%
type(df.loc[:, ['title','rating']] )
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#                                           title rating  \
# 0                                  White Chicks  PG-13
# 1                           Lucky Number Slevin      R
# 2                                Grey's Anatomy  TV-14
# 3                                  Prison Break  TV-14
# 4                         How I Met Your Mother  TV-PG
# 5                                  Supernatural  TV-14
# 6                                  Breaking Bad  TV-MA
# 7                           The Vampire Diaries  TV-14
# 8                              The Walking Dead  TV-MA
# 9                           Pretty Little Liars  TV-14
# 10                             Once Upon a Time  TV-PG
# 11                                     Sherlock  TV-14
# 12                                   Death Note  TV-14
# 13                                       Naruto  TV-PG
# 14                                   The Hunter      R
# 15                        Lottie Dottie Chicken   TV-Y
# ...

# %%
df.loc[1,'rating']
# Out:
# 'R'

# %%
df.at[1,'rating'] # 무조건 한개
# Out:
# 'R'

# %%
# %timeit df.loc[1,'rating']
# Out:
# 8.2 µs ± 288 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %timeit df.at[1,'rating']  #속도가 빨라
# Out:
# 6.26 µs ± 668 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
df.loc[1,'rating'] ='문근영'

# %%
df
# Out:
#                                           title rating  \
# 0                                  White Chicks  PG-13
# 1                           Lucky Number Slevin    문근영
# 2                                Grey's Anatomy  TV-14
# 3                                  Prison Break  TV-14
# 4                         How I Met Your Mother  TV-PG
# 5                                  Supernatural  TV-14
# 6                                  Breaking Bad  TV-MA
# 7                           The Vampire Diaries  TV-14
# 8                              The Walking Dead  TV-MA
# 9                           Pretty Little Liars  TV-14
# 10                             Once Upon a Time  TV-PG
# 11                                     Sherlock  TV-14
# 12                                   Death Note  TV-14
# 13                                       Naruto  TV-PG
# 14                                   The Hunter      R
# 15                        Lottie Dottie Chicken   TV-Y
# ...

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=1000, step=1),
#  Index(['title', 'rating', 'ratingLevel', 'ratingDescription', 'release year',
#         'user rating score', 'user rating size'],
#        dtype='object')]

# %%
df.iat[1,1]  #index or inteager pandas에서는 정수 베이스
# Out:
# '문근영'

# %%
df.at[1,1] #label base 이름을 지정 하기 때문에
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-ffb821b75380> in <module>()
# ----> 1 df.at[1,1]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    2139                 raise ValueError('Invalid call for scalar access (getting)!')
#    2140
# -> 2141         key = self._convert_key(key)
#    2142         return self.obj._get_value(*key, takeable=self._takeable)
#    2143
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_key(self, key, is_setter)
#    2225             else:
#    2226                 if is_integer(i):
# -> 2227                     raise ValueError("At based indexing on an non-integer "
#    2228                                      "index can only have non-integer "
#    2229                                      "indexers")
#
# ...

# %%
# %timeit df.iat[1,1] # 2,2 가져오기 # i자 붙은 애를 훨씬 더 많이쓴다.
# Out:
# 6.48 µs ± 700 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
df.iloc[1:3, 1] # 파이썬 list와 똑같다
# Out:
# 1      문근영
# 2    TV-14
# Name: rating, dtype: object

# %%
df.loc[1:3,'rating'] #pandas 3포함
# Out:
# 1      문근영
# 2    TV-14
# 3    TV-14
# Name: rating, dtype: object

# %%
#어떠한 특정한 영역을 바꾸고 싶을 때
