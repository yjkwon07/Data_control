# %% [markdown]
# pandas는 전처리와 , 통계분석(eda) explorely data analisty

# %%
import pandas as pd

# %%
pd.__version__ # 0. 버전은 내맘대로 바꿀 수 있다.
# Out:
# '0.23.3'

# %%
# !pip install -U pandas
# Out:
# Requirement already up-to-date: pandas in c:\programdata\anaconda3\lib\site-packages (0.23.3)
# Requirement not upgraded as not directly required: numpy>=1.9.0 in c:\programdata\anaconda3\lib\site-packages (from pandas) (1.14.0)
# Requirement not upgraded as not directly required: python-dateutil>=2.5.0 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2.6.1)
# Requirement not upgraded as not directly required: pytz>=2011k in c:\programdata\anaconda3\lib\site-packages (from pandas) (2017.3)
# Requirement not upgraded as not directly required: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.5.0->pandas) (1.11.0)
# tensorflow-gpu 1.7.0 has requirement tensorboard<1.8.0,>=1.7.0, but you'll have tensorboard 1.8.0 which is incompatible.
# You are using pip version 10.0.1, however version 18.0 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# read  -> data frame을 불러온다 .
# 판다스는 기본적인 프레임이 데이터 프레임

df = pd.read_csv('data-netflix.csv')
df.head()
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
#
#    release year  user rating score  user rating size
# 0          2004               82.0                80
# 1          2006                NaN                82
# 2          2016               98.0                80
# 3          2008               98.0                80
# 4          2014               94.0                80

# %%
type(df) #DataFrame class (pascal 방식으로 표현되었기 때문에)
# Out:
# pandas.core.frame.DataFrame

# %%
dir(df) #판다스는 전처리, eda
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...

# %%
df
# Out:
#                                           title rating  \
# 0                                  White Chicks  PG-13
# 1                           Lucky Number Slevin      R
# 2                                Grey's Anatomy  TV-14
# 3                                  Prison Break  TV-14
# 4                         How I Met Your Mother  TV-PG
# 5                                  Supernatural  TV-14
# 6                                  Breaking Bad  TV-MA
# 7                           The Vampire Diaries  TV-14
# 8                              The Walking Dead  TV-MA
# 9                           Pretty Little Liars  TV-14
# 10                             Once Upon a Time  TV-PG
# 11                                     Sherlock  TV-14
# 12                                   Death Note  TV-14
# 13                                       Naruto  TV-PG
# 14                                   The Hunter      R
# 15                        Lottie Dottie Chicken   TV-Y
# ...

# %% [markdown]
# # 기본 5개 분석

# %%
df.info() 
# 컬럼은 속성(attribute) 
# row는 관측치 observation 

# non-null -> 누락된 데이터가 없다.

# pandas 데이터 형태는 크게 두 가지 (숫자형, 문자형)
# 판다스는 실생활에서 복소수를 잘 상용안하기 때문에 bool int 상속 받기 때문에 int 
# title- > string
# rating -> string
# level -> string
# 판다스는 모든 데이터를 메모리에 올린다. -> 속도가 빨라
# 단점: 메모리보다 큰 범위를 해결 할 수없다 
# 엄청 큰 데이터는 pd 사용하기 어려워
# dask- > 디스크기반이기 때문에 가능해 

#판다스 후 봐야할 5가지
# data 잘 불러왔는디 확인
# info 
# describe
# sample
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
# title                1000 non-null object
# rating               1000 non-null object
# ratingLevel          941 non-null object
# ratingDescription    1000 non-null int64
# release year         1000 non-null int64
# user rating score    605 non-null float64
# user rating size     1000 non-null int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 54.8+ KB

# %%
df.describe() 
# like a summary  
# 판다스 만든 사람이 r좋아했어 그른디 파이썬을 좋아했어 
# 숫자형있는 애만 summary나온다.
# Out:
#        ratingDescription  release year  user rating score  user rating size
# count         1000.00000   1000.000000         605.000000       1000.000000
# mean            67.36600   2010.335000          84.094215         80.783000
# std             30.78561      8.877927          12.344371          0.973066
# min             10.00000   1940.000000          55.000000         80.000000
# 25%             35.00000   2007.000000          75.000000         80.000000
# 50%             60.00000   2015.000000          88.000000         80.000000
# 75%             90.00000   2016.000000          95.000000         82.000000
# max            124.00000   2017.000000          99.000000         82.000000

# %%
df.head().info() # dataframe이기 때문에 info() 사용 가능
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 7 columns):
# title                5 non-null object
# rating               5 non-null object
# ratingLevel          5 non-null object
# ratingDescription    5 non-null int64
# release year         5 non-null int64
# user rating score    4 non-null float64
# user rating size     5 non-null int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 360.0+ bytes

# %%
df.head().describe() # 보통 달라
# Out:
#        ratingDescription  release year  user rating score  user rating size
# count           5.000000      5.000000           4.000000          5.000000
# mean           86.000000   2009.600000          93.000000         80.400000
# std            11.401754      5.176872           7.571878          0.894427
# min            70.000000   2004.000000          82.000000         80.000000
# 25%            80.000000   2006.000000          91.000000         80.000000
# 50%            90.000000   2008.000000          96.000000         80.000000
# 75%            90.000000   2014.000000          98.000000         80.000000
# max           100.000000   2016.000000          98.000000         82.000000

# %%
df.tail().describe()
# Out:
#        ratingDescription  release year  user rating score  user rating size
# count           5.000000      5.000000           2.000000               5.0
# mean           45.000000   2012.800000          88.500000              81.0
# std            13.693064      5.630275          12.020815               1.0
# min            35.000000   2003.000000          80.000000              80.0
# 25%            35.000000   2013.000000          84.250000              80.0
# 50%            35.000000   2016.000000          88.500000              81.0
# 75%            60.000000   2016.000000          92.750000              82.0
# max            60.000000   2016.000000          97.000000              82.0

# %%
df.sample() # 랜덤하게 뽑는다.
# Out:
#                            title rating  \
# 341  How to Get Away with Murder  TV-14
#
#                                            ratingLevel  ratingDescription  \
# 341  Parents strongly cautioned. May be unsuitable ...                 90
#
#      release year  user rating score  user rating size
# 341          2016               95.0                80

# %%
df.sample(10) #그냥 느낌 보는거야
# Out:
#                                      title rating  \
# 459                    The Vampire Diaries  TV-14
# 970                                  Annie     PG
# 485                         American Crime  TV-14
# 788                       The Pirate Fairy      G
# 501                             Scooby-Doo     PG
# 796                               Quackerz     PG
# 525  Thomas & Friends: King of the Railway   TV-G
# 19                                 The 100     NR
# 95                             Sand Castle  TV-MA
# 149                          Almost Adults     NR
#
#                                            ratingLevel  ratingDescription  \
# 459  Parents strongly cautioned. May be unsuitable ...                 90
# 970                     adult content and mld violence                 60
# 485  Parents strongly cautioned. May be unsuitable ...                 90
# 788          General Audiences. Suitable for all ages.                 35
# ...

# %%
# 원래 처음에 데이터 다 보는디 보기 귀찮으니 느낌볼려고 sample

# %%
df2 = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data")

# %%
df2 
# row는 관측치가 나와야한다. column은 변수 구분된 애로 
# 2차원 형태로 나와야한다. 
# db는 참조무결성으로 인해 테이블로 쪼개었지만, 
# 이 데이터 분석은 쪼개진 데이터를 붙여야한다.
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# 5    4.6  3.4  1.4  0.3     Iris-setosa
# 6    5.0  3.4  1.5  0.2     Iris-setosa
# 7    4.4  2.9  1.4  0.2     Iris-setosa
# 8    4.9  3.1  1.5  0.1     Iris-setosa
# 9    5.4  3.7  1.5  0.2     Iris-setosa
# 10   4.8  3.4  1.6  0.2     Iris-setosa
# 11   4.8  3.0  1.4  0.1     Iris-setosa
# 12   4.3  3.0  1.1  0.1     Iris-setosa
# 13   5.8  4.0  1.2  0.2     Iris-setosa
# 14   5.7  4.4  1.5  0.4     Iris-setosa
# 15   5.4  3.9  1.3  0.4     Iris-setosa
# 16   5.1  3.5  1.4  0.3     Iris-setosa
# 17   5.7  3.8  1.7  0.3     Iris-setosa
# 18   5.1  3.8  1.5  0.3     Iris-setosa
# 19   5.4  3.4  1.7  0.2     Iris-setosa
# 20   5.1  3.7  1.5  0.4     Iris-setosa
# 21   4.6  3.6  1.0  0.2     Iris-setosa
# ...

# %% [markdown]
# # header = None

# %%
# 이 데이터는 헤더가 없다.
# 그래서 
df2 = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data", header= None)

# %%
df2 # 판다스 데이터 프레임으로 인덱스를 붙여줬다. 
    # 컬럼 네임 0, 1, 2, 3, 4 -> ==인덱스 [인덱싱, 슬라이싱 가능 즉, 시퀀시]
    # 한줄 한열 컴럼은 serise
    #  row -> 인덱스 
    # 시퀀스 하게 나옴
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# 5    5.4  3.9  1.7  0.4     Iris-setosa
# 6    4.6  3.4  1.4  0.3     Iris-setosa
# 7    5.0  3.4  1.5  0.2     Iris-setosa
# 8    4.4  2.9  1.4  0.2     Iris-setosa
# 9    4.9  3.1  1.5  0.1     Iris-setosa
# 10   5.4  3.7  1.5  0.2     Iris-setosa
# 11   4.8  3.4  1.6  0.2     Iris-setosa
# 12   4.8  3.0  1.4  0.1     Iris-setosa
# 13   4.3  3.0  1.1  0.1     Iris-setosa
# 14   5.8  4.0  1.2  0.2     Iris-setosa
# 15   5.7  4.4  1.5  0.4     Iris-setosa
# 16   5.4  3.9  1.3  0.4     Iris-setosa
# 17   5.1  3.5  1.4  0.3     Iris-setosa
# 18   5.7  3.8  1.7  0.3     Iris-setosa
# 19   5.1  3.8  1.5  0.3     Iris-setosa
# 20   5.4  3.4  1.7  0.2     Iris-setosa
# 21   5.1  3.7  1.5  0.4     Iris-setosa
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 5 columns):
# 5.1            149 non-null float64
# 3.5            149 non-null float64
# 1.4            149 non-null float64
# 0.2            149 non-null float64
# Iris-setosa    149 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
df2.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
df2.describe()
# Out:
#               5.1         3.5         1.4         0.2
# count  149.000000  149.000000  149.000000  149.000000
# mean     5.848322    3.051007    3.774497    1.205369
# std      0.828594    0.433499    1.759651    0.761292
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
df2.sample()
# Out:
#     5.1  3.5  1.4  0.2  Iris-setosa
# 48  5.0  3.3  1.4  0.2  Iris-setosa

# %%
df = pd.read_csv("data-netflix.csv", header=2)

# %%
df.info() 
#헤더의 위에거를 다 삭제 # 빅데이터에서는 한 두개 영향이 크게 안미침  
# small data에서는 크게 미침
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 998 entries, 0 to 997
# Data columns (total 7 columns):
# Lucky Number Slevin                                   998 non-null object
# R                                                     998 non-null object
# strong violence, sexual content and adult language    939 non-null object
# 100                                                   998 non-null int64
# 2006                                                  998 non-null int64
# NA                                                    604 non-null float64
# 82                                                    998 non-null int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 54.7+ KB

# %%
df = pd.read_csv("data-netflix.csv", index_col="title")
#기준 # index는 헥싱이랑 똑같다. -> == dict

# %%
df.sample(10)
# Out:
#                                        rating  \
# title
# Arrow                                   TV-14
# Honey, I Shrunk the Kids                   PG
# Raising Hope                            TV-14
# Agent F.O.X.                               PG
# O Amor no DivÃ£                         TV-MA
# Kung Fu Panda                              PG
# Little Baby Bum: Nursery Rhyme Friends   TV-Y
# Annie                                      PG
# Once Upon a Time                        TV-PG
# The Prince of Egypt                        PG
#
#                                                                               ratingLevel  \
# title
# Arrow                                   Parents strongly cautioned. May be unsuitable ...
# Honey, I Shrunk the Kids                Parental guidance suggested. May not be suitab...
# Raising Hope                            Parents strongly cautioned. May be unsuitable ...
# ...

# %%
df = pd.read_csv("data-netflix.csv", usecols= ['title', 'rating', 'release year']) 
# 아주 안좋아 가져올 때 부터 버리는건 바보 또는 초 전문가
df # 메모리에 올리니깐 , -> knowledege picture ~~
# Out:
#                                           title rating  release year
# 0                                  White Chicks  PG-13          2004
# 1                           Lucky Number Slevin      R          2006
# 2                                Grey's Anatomy  TV-14          2016
# 3                                  Prison Break  TV-14          2008
# 4                         How I Met Your Mother  TV-PG          2014
# 5                                  Supernatural  TV-14          2016
# 6                                  Breaking Bad  TV-MA          2013
# 7                           The Vampire Diaries  TV-14          2017
# 8                              The Walking Dead  TV-MA          2015
# 9                           Pretty Little Liars  TV-14          2016
# 10                             Once Upon a Time  TV-PG          2016
# 11                                     Sherlock  TV-14          2016
# 12                                   Death Note  TV-14          2006
# ...

# %% [markdown]
# Ad hoc # 특정 문제에는 특정 해결만 있다.(일반적인 해답이 없다.)<br/>
# no free lunch # 특정한 목적에는 특정한 노력을 해야한다. (일반적인 해답이 없다.)

# %%
df = pd.read_csv("data-netflix.csv", na_values= ['']) 
#널값도 정할 수 잇따. NA -> not available #ad hoc 
#강사는 안씀

# %%
df = pd.read_csv("data-netflix.csv", skip_blank_lines=False) #빈줄 생각할까?

# %%
df = pd.read_csv("data-netflix.csv", skiprows=[1,3,7]) #해당 인덱스 삭제

# %%
df = pd.read_csv("data-netflix.csv", skipfooter=2, engine='python') 
# c-->1 python -> 5 ~100배 병목현상에서는 c언어  
# c -> 한글이나 이상한거 나오면 골치가 아파 3 
# 파이썬은 기본이 유니코드

# %%
import seaborn as sns

# %%
data = sns.load_dataset('tips', engine ='python')
#안불러오지면 encoding , engine = 'python'

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.2 KB

# %%
data.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
data.sample()
# Out:
#     total_bill   tip   sex smoker  day    time  size
# 34       17.78  3.27  Male     No  Sat  Dinner     2

# %% [markdown]
# # numpy

# %%
df = pd.read_csv("data-netflix.csv", nrows=100) 
# 테스트 해볼 때, 1000만개중에서 몇개만 가져온다. 프로토타입 분석할 때 쓰임
df.shape
# df.info하면 할 필요가 없어  
# 판다스는 넘파이도 포함한다. 
# 수치해석은 정확도가 중요하다.
#  넘파이는 수치해성의 기본라이브러리 속도가 빨라 
#  판다스는 넘파이 기반이다.
# Out:
# (100, 7)

# %%
df = pd.read_excel("data-netflix.xlsx", sheetname=0)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-78-31272a911642> in <module>()
# ----> 1 df = pd.read_excel("data-netflix.xlsx")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# ...

# %%
movies_json= pd.read_json('data-netflix.json')

# %%
movies_json
# Out:
#                                           title rating  \
# 0                                  White Chicks  PG-13
# 1                           Lucky Number Slevin      R
# 10                             Once Upon a Time  TV-PG
# 100          The Life Aquatic with Steve Zissou      R
# 101                         Lucky Number Slevin      R
# 102                                  The L Word  TV-MA
# 103                           The Office (U.S.)  TV-14
# 104                                     30 Rock  TV-14
# 105                                     Mad Men  TV-14
# 106           It's Always Sunny in Philadelphia  TV-MA
# 107                             Californication  TV-MA
# 108                        Parks and Recreation  TV-14
# 109                                     Friends  TV-14
# 11                                     Sherlock  TV-14
# 110                            Shameless (U.S.)  TV-MA
# 111                                  Portlandia  TV-14
# ...

# %%
movies_json.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 7 columns):
# title                1000 non-null object
# rating               1000 non-null object
# ratingLevel          941 non-null object
# ratingDescription    1000 non-null int64
# release year         1000 non-null int64
# user rating score    605 non-null float64
# user rating size     1000 non-null int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 62.5+ KB

# %%
#html 데이터는 우아하지 않아, 미쳐버려-> beautifulsoup or lxml
# 테이블 데이터는 잘 불러와

# %%
df = pd.read_pickle('data-netflix.p') 
#파이썬에서 객체를 저장할 때  #직렬화 방식 
# 예전에 버전에러가 나서 신뢰하지 않은 프로그래머가 많아짐
df.head()
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
#
#    release year  user rating score  user rating size
# 0          2004               82.0                80
# 1          2006                NaN                82
# 2          2016               98.0                80
# 3          2008               98.0                80
# 4          2014               94.0                80

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# 중간 저장 값을 피클로 저장
# 피클은 확장자 내맘대러 만들 수 잇다.

# %%
import sqlite3

# %%
conn = sqlite3.connect('data-netflix.sqlite')

# %%
df = pd.read_sql_query("select * from data_netflix", conn)

# %%
df.head()
# Out:
#    ogc_fid                  title rating  \
# 0        1           White Chicks  PG-13
# 1        2    Lucky Number Slevin      R
# 2        3         Grey's Anatomy  TV-14
# 3        4           Prison Break  TV-14
# 4        5  How I Met Your Mother  TV-PG
#
#                                          ratinglevel ratingdescription  \
# 0  crude and sexual humor, language and some drug...                80
# 1  strong violence, sexual content and adult lang...               100
# 2  Parents strongly cautioned. May be unsuitable ...                90
# 3  Parents strongly cautioned. May be unsuitable ...                90
# 4  Parental guidance suggested. May not be suitab...                70
#
#   release year user rating score user rating size
# 0         2004                82               80
# 1         2006                NA               82
# 2         2016                98               80
# 3         2008                98               80
# ...

# %%
# dataframe 만드는 방법 3가지 (class)
# 함수로 만드는방법(read_)
# 인스턴스 
# from 방법  (to ~)

# %%
df = pd.read_csv("data-netflix.csv", encoding='utf-8')

# %%
df.to_html('ss.html')
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-98-552cd94d05e9> in <module>()
# ----> 1 df.to_html('ss.html')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in to_html(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, bold_rows, classes, escape, max_rows, max_cols, show_dimensions, notebook, decimal, border, table_id)
#    2035                                            decimal=decimal, table_id=table_id)
#    2036         # TODO: a generic formatter wld b in DataFrameFormatter
# -> 2037         formatter.to_html(classes=classes, notebook=notebook, border=border)
#    2038
#    2039         if buf is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\format.py in to_html(self, classes, notebook, border)
# ...

# %%
df = pd.read_csv('data-netflix.csv')
df['title'] # dict 판다스는 여러개 복수가 있으면 list
df[['title','rating']]
# Out:
#                                           title rating
# 0                                  White Chicks  PG-13
# 1                           Lucky Number Slevin      R
# 2                                Grey's Anatomy  TV-14
# 3                                  Prison Break  TV-14
# 4                         How I Met Your Mother  TV-PG
# 5                                  Supernatural  TV-14
# 6                                  Breaking Bad  TV-MA
# 7                           The Vampire Diaries  TV-14
# 8                              The Walking Dead  TV-MA
# 9                           Pretty Little Liars  TV-14
# 10                             Once Upon a Time  TV-PG
# 11                                     Sherlock  TV-14
# 12                                   Death Note  TV-14
# 13                                       Naruto  TV-PG
# 14                                   The Hunter      R
# 15                        Lottie Dottie Chicken   TV-Y
# ...

# %%
df['title'] # dataframe 한 컬럼은 시리즈
# Out:
# 0                                    White Chicks
# 1                             Lucky Number Slevin
# 2                                  Grey's Anatomy
# 3                                    Prison Break
# 4                           How I Met Your Mother
# 5                                    Supernatural
# 6                                    Breaking Bad
# 7                             The Vampire Diaries
# 8                                The Walking Dead
# 9                             Pretty Little Liars
# 10                               Once Upon a Time
# 11                                       Sherlock
# 12                                     Death Note
# 13                                         Naruto
# 14                                     The Hunter
# 15                          Lottie Dottie Chicken
# 16                                          Arrow
# 17                                   Black Mirror
# 18                                  The Originals
# ...

# %%
df[['title']] #dataframe 2차원
# Out:
#                                           title
# 0                                  White Chicks
# 1                           Lucky Number Slevin
# 2                                Grey's Anatomy
# 3                                  Prison Break
# 4                         How I Met Your Mother
# 5                                  Supernatural
# 6                                  Breaking Bad
# 7                           The Vampire Diaries
# 8                              The Walking Dead
# 9                           Pretty Little Liars
# 10                             Once Upon a Time
# 11                                     Sherlock
# 12                                   Death Note
# 13                                       Naruto
# 14                                   The Hunter
# 15                        Lottie Dottie Chicken
# 16                                        Arrow
# 17                                 Black Mirror
# 18                                The Originals
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
# title                1000 non-null object
# rating               1000 non-null object
# ratingLevel          941 non-null object
# ratingDescription    1000 non-null int64
# release year         1000 non-null int64
# user rating score    605 non-null float64
# user rating size     1000 non-null int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 54.8+ KB

# %%
df = pd.read_csv('data-netflix.csv',engine='python')

# %%
df.to_html('tt.html')
