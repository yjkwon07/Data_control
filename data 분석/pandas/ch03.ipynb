# %%
import pandas as pd
df = pd.read_csv('./data/data-zillow.csv', sep=',', engine='python')

# %%
df.head()
# Out:
#          Date  RegionID    RegionName State                           Metro  \
# 0  2017-05-31      6181      New York    NY                        New York
# 1  2017-05-31     12447   Los Angeles    CA  Los Angeles-Long Beach-Anaheim
# 2  2017-05-31     17426       Chicago    IL                         Chicago
# 3  2017-05-31     13271  Philadelphia    PA                    Philadelphia
# 4  2017-05-31     40326       Phoenix    AZ                         Phoenix
#
#          County  SizeRank    Zhvi
# 0        Queens         0  672400
# 1   Los Angeles         1  629900
# 2          Cook         2  222700
# 3  Philadelphia         3  137300
# 4      Maricopa         4  211300

# %%
df
# Out:
#              Date  RegionID         RegionName State  \
# 0      2017-05-31      6181           New York    NY
# 1      2017-05-31     12447        Los Angeles    CA
# 2      2017-05-31     17426            Chicago    IL
# 3      2017-05-31     13271       Philadelphia    PA
# 4      2017-05-31     40326            Phoenix    AZ
# 5      2017-05-31     18959          Las Vegas    NV
# 6      2017-05-31     54296          San Diego    CA
# 7      2017-05-31     38128             Dallas    TX
# 8      2017-05-31     33839           San Jose    CA
# 9      2017-05-31     25290       Jacksonville    FL
# 10     2017-05-31     20330      San Francisco    CA
# 11     2017-05-31     10221             Austin    TX
# 12     2017-05-31     17762            Detroit    MI
# 13     2017-05-31     10920           Columbus    OH
# 14     2017-05-31     32811            Memphis    TN
# 15     2017-05-31     24043          Charlotte    NC
# 16     2017-05-31     17933            El Paso    TX
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10830 entries, 0 to 10829
# Data columns (total 8 columns):
# Date          10830 non-null object
# RegionID      10830 non-null int64
# RegionName    10830 non-null object
# State         10830 non-null object
# Metro         10256 non-null object
# County        10830 non-null object
# SizeRank      10830 non-null int64
# Zhvi          10830 non-null int64
# dtypes: int64(3), object(5)
# memory usage: 677.0+ KB

# %%
df.describe()
# Out:
#             RegionID      SizeRank          Zhvi
# count   10830.000000  10830.000000  1.083000e+04
# mean    84344.818837   5414.500000  2.503076e+05
# std    125679.686534   3126.496042  2.565582e+05
# min      3301.000000      0.000000  3.740000e+04
# 25%     19346.250000   2707.250000  1.269000e+05
# 50%     35444.500000   5414.500000  1.818000e+05
# 75%     52608.250000   8121.750000  2.823500e+05
# max    737791.000000  10829.000000  6.343800e+06

# %%
df["RegionName"]
# Out:
# 0                 New York
# 1              Los Angeles
# 2                  Chicago
# 3             Philadelphia
# 4                  Phoenix
# 5                Las Vegas
# 6                San Diego
# 7                   Dallas
# 8                 San Jose
# 9             Jacksonville
# 10           San Francisco
# 11                  Austin
# 12                 Detroit
# 13                Columbus
# 14                 Memphis
# 15               Charlotte
# 16                 El Paso
# 17                  Boston
# 18                 Seattle
# 19               Baltimore
# 20                  Denver
# 21              Washington
# 22               Nashville
# 23               Milwaukee
# 24                  Tucson
# 25                Portland
# 26           Oklahoma City
# 27                   Omaha
# 28             Albuquerque
# 29                  Fresno
#                ...
# 10800         Mount Sidney
# 10801          Cedar Grove
# 10802                Clark
# ...

# %%
df.RegionName
# Out:
# 0                 New York
# 1              Los Angeles
# 2                  Chicago
# 3             Philadelphia
# 4                  Phoenix
# 5                Las Vegas
# 6                San Diego
# 7                   Dallas
# 8                 San Jose
# 9             Jacksonville
# 10           San Francisco
# 11                  Austin
# 12                 Detroit
# 13                Columbus
# 14                 Memphis
# 15               Charlotte
# 16                 El Paso
# 17                  Boston
# 18                 Seattle
# 19               Baltimore
# 20                  Denver
# 21              Washington
# 22               Nashville
# 23               Milwaukee
# 24                  Tucson
# 25                Portland
# 26           Oklahoma City
# 27                   Omaha
# 28             Albuquerque
# 29                  Fresno
#                ...
# 10800         Mount Sidney
# 10801          Cedar Grove
# 10802                Clark
# ...

# %%
df.loc[:,'RegionName']
# Out:
# 0                 New York
# 1              Los Angeles
# 2                  Chicago
# 3             Philadelphia
# 4                  Phoenix
# 5                Las Vegas
# 6                San Diego
# 7                   Dallas
# 8                 San Jose
# 9             Jacksonville
# 10           San Francisco
# 11                  Austin
# 12                 Detroit
# 13                Columbus
# 14                 Memphis
# 15               Charlotte
# 16                 El Paso
# 17                  Boston
# 18                 Seattle
# 19               Baltimore
# 20                  Denver
# 21              Washington
# 22               Nashville
# 23               Milwaukee
# 24                  Tucson
# 25                Portland
# 26           Oklahoma City
# 27                   Omaha
# 28             Albuquerque
# 29                  Fresno
#                ...
# 10800         Mount Sidney
# 10801          Cedar Grove
# 10802                Clark
# ...

# %%
df.iloc[:,2].head()
# Out:
# 0        New York
# 1     Los Angeles
# 2         Chicago
# 3    Philadelphia
# 4         Phoenix
# Name: RegionName, dtype: object

# %%
df.describe()
# Out:
#             RegionID      SizeRank          Zhvi
# count   10830.000000  10830.000000  1.083000e+04
# mean    84344.818837   5414.500000  2.503076e+05
# std    125679.686534   3126.496042  2.565582e+05
# min      3301.000000      0.000000  3.740000e+04
# 25%     19346.250000   2707.250000  1.269000e+05
# 50%     35444.500000   5414.500000  1.818000e+05
# 75%     52608.250000   8121.750000  2.823500e+05
# max    737791.000000  10829.000000  6.343800e+06

# %%
df.count()
# Out:
# Date          10830
# RegionID      10830
# RegionName    10830
# State         10830
# Metro         10256
# County        10830
# SizeRank      10830
# Zhvi          10830
# dtype: int64

# %%
df.min()
# Out:
# Date          2017-05-31
# RegionID            3301
# RegionName     Abbeville
# State                 AK
# County            Acadia
# SizeRank               0
# Zhvi               37400
# dtype: object

# %%
df.skew()
# Out:
# RegionID    1.973159
# SizeRank    0.000000
# Zhvi        6.714811
# dtype: float64

# %%
df.kurt()
# Out:
# RegionID     2.291461
# SizeRank    -1.200000
# Zhvi        82.042387
# dtype: float64

# %%
df.cov()
# Out:
#               RegionID      SizeRank          Zhvi
# RegionID  1.579538e+10  2.044245e+07 -1.037760e+09
# SizeRank  2.044245e+07  9.774978e+06 -9.274275e+07
# Zhvi     -1.037760e+09 -9.274275e+07  6.582212e+10

# %%
df.iloc[:, 1:4]
# Out:
#        RegionID         RegionName State
# 0          6181           New York    NY
# 1         12447        Los Angeles    CA
# 2         17426            Chicago    IL
# 3         13271       Philadelphia    PA
# 4         40326            Phoenix    AZ
# 5         18959          Las Vegas    NV
# 6         54296          San Diego    CA
# 7         38128             Dallas    TX
# 8         33839           San Jose    CA
# 9         25290       Jacksonville    FL
# 10        20330      San Francisco    CA
# 11        10221             Austin    TX
# 12        17762            Detroit    MI
# 13        10920           Columbus    OH
# 14        32811            Memphis    TN
# 15        24043          Charlotte    NC
# 16        17933            El Paso    TX
# 17        44269             Boston    MA
# 18        16037            Seattle    WA
# 19         3523          Baltimore    MD
# 20        11093             Denver    CO
# 21        41568         Washington    DC
# ...

# %%
df.iat[1,4]
# Out:
# 'Los Angeles-Long Beach-Anaheim'

# %%
df.loc[1:7, 'Metro':'County']
# Out:
#                             Metro        County
# 1  Los Angeles-Long Beach-Anaheim   Los Angeles
# 2                         Chicago          Cook
# 3                    Philadelphia  Philadelphia
# 4                         Phoenix      Maricopa
# 5                       Las Vegas         Clark
# 6                       San Diego     San Diego
# 7               Dallas-Fort Worth        Dallas

# %%
df['문근영'] = 3 # 없는 컬럼

# %%
df
# Out:
#              Date  RegionID         RegionName State  \
# 0      2017-05-31      6181           New York    NY
# 1      2017-05-31     12447        Los Angeles    CA
# 2      2017-05-31     17426            Chicago    IL
# 3      2017-05-31     13271       Philadelphia    PA
# 4      2017-05-31     40326            Phoenix    AZ
# 5      2017-05-31     18959          Las Vegas    NV
# 6      2017-05-31     54296          San Diego    CA
# 7      2017-05-31     38128             Dallas    TX
# 8      2017-05-31     33839           San Jose    CA
# 9      2017-05-31     25290       Jacksonville    FL
# 10     2017-05-31     20330      San Francisco    CA
# 11     2017-05-31     10221             Austin    TX
# 12     2017-05-31     17762            Detroit    MI
# 13     2017-05-31     10920           Columbus    OH
# 14     2017-05-31     32811            Memphis    TN
# 15     2017-05-31     24043          Charlotte    NC
# 16     2017-05-31     17933            El Paso    TX
# ...

# %%
del df['문근영'] #파이썬 기반이기 때문에 가능하다. 추가 삭제는 [], del ~~

# %%
df.iloc[7,4:8]
# Out:
# Metro       Dallas-Fort Worth
# County                 Dallas
# SizeRank                    7
# Zhvi                   164700
# Name: 7, dtype: object

# %%
df.loc[11,:]
# Out:
# Date          2017-05-31
# RegionID           10221
# RegionName        Austin
# State                 TX
# Metro             Austin
# County            Travis
# SizeRank              11
# Zhvi              321600
# Name: 11, dtype: object

# %%
df.loc[1,['State','County']]
# Out:
# State              CA
# County    Los Angeles
# Name: 1, dtype: object

# %%
df.loc[0] # 행 전체
# Out:
# Date          2017-05-31
# RegionID            6181
# RegionName      New York
# State                 NY
# Metro           New York
# County            Queens
# SizeRank               0
# Zhvi              672400
# Name: 0, dtype: object

# %%
df.loc[df.Date=='2017-05-31'] # 조건
# Out:
#              Date  RegionID         RegionName State  \
# 0      2017-05-31      6181           New York    NY
# 1      2017-05-31     12447        Los Angeles    CA
# 2      2017-05-31     17426            Chicago    IL
# 3      2017-05-31     13271       Philadelphia    PA
# 4      2017-05-31     40326            Phoenix    AZ
# 5      2017-05-31     18959          Las Vegas    NV
# 6      2017-05-31     54296          San Diego    CA
# 7      2017-05-31     38128             Dallas    TX
# 8      2017-05-31     33839           San Jose    CA
# 9      2017-05-31     25290       Jacksonville    FL
# 10     2017-05-31     20330      San Francisco    CA
# 11     2017-05-31     10221             Austin    TX
# 12     2017-05-31     17762            Detroit    MI
# 13     2017-05-31     10920           Columbus    OH
# 14     2017-05-31     32811            Memphis    TN
# 15     2017-05-31     24043          Charlotte    NC
# 16     2017-05-31     17933            El Paso    TX
# ...

# %%
# at은 셀만
# loc 행 또는 행과 열 / 셀도 포함
# 열은 4가지 dict, atr , loc, iloc
# 셀은 4가지 loc iloc at iat
# 보통 iloc 속도측면을 잘 알고 판단하기를~

# %%
df.loc[df.State == 'CA',[1,1]] #  loc이기 때문에 , label 사용을 해야한다.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-45778587712b> in <module>()
# ----> 1 df.loc[df.State == 'CA',[1,1]] #  loc이기 때문에 , label 사용을 해야한다.
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1470             except (KeyError, IndexError):
#    1471                 pass
# -> 1472             return self._getitem_tuple(key)
#    1473         else:
#    1474             # we by definition only have the 0th axis
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     888                 continue
#     889
# --> 890             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     891
#     892         return retval
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
# ...

# %%
df.loc[df['State']== 'CA'] # <- 함수형 패러다임
# Out:
#              Date  RegionID        RegionName State  \
# 1      2017-05-31     12447       Los Angeles    CA
# 6      2017-05-31     54296         San Diego    CA
# 8      2017-05-31     33839          San Jose    CA
# 10     2017-05-31     20330     San Francisco    CA
# 29     2017-05-31     18203            Fresno    CA
# 30     2017-05-31     20288        Sacramento    CA
# 32     2017-05-31     46298        Long Beach    CA
# 38     2017-05-31     13072           Oakland    CA
# 49     2017-05-31     16764           Anaheim    CA
# 50     2017-05-31     47568         Santa Ana    CA
# 55     2017-05-31     47401         Riverside    CA
# 58     2017-05-31      3506       Bakersfield    CA
# 65     2017-05-31      7266          Stockton    CA
# 70     2017-05-31     25934           Modesto    CA
# 83     2017-05-31     20328    San Bernardino    CA
# 84     2017-05-31     24225            Corona    CA
# 85     2017-05-31     51405       Chula Vista    CA
# ...

# %%
df.loc[df.Metro == 'New York', 'County']
# Out:
# 0             Queens
# 63             Essex
# 72            Hudson
# 138      Westchester
# 176          Passaic
# 225            Union
# 291        Middlesex
# 338            Ocean
# 387            Ocean
# 402          Passaic
# 406         Dutchess
# 521      Westchester
# 541            Ocean
# 564          Passaic
# 582           Hudson
# 591            Essex
# 611      Westchester
# 631           Hudson
# 651           Nassau
# 716           Hudson
# 727      Westchester
# 732           Nassau
# 735         Monmouth
# 750            Essex
# 760          Passaic
# 779            Ocean
# 781            Union
# 787        Middlesex
# 800           Orange
# 806        Middlesex
#             ...
# 9591       Hunterdon
# 9614         Suffolk
# 9714         Suffolk
# 9732           Ocean
# 9777           Ocean
# 9791           Ocean
# 9805        Monmouth
# 9817           Ocean
# 9819        Monmouth
# 9820           Ocean
# 9860        Monmouth
# 9939       Hunterdon
# ...

# %%
df.sort_values('Metro')
# Out:
#              Date  RegionID       RegionName State     Metro        County  \
# 9851   2017-05-31     48458         Westport    WA  Aberdeen  Grays Harbor
# 4996   2017-05-31     36873             Elma    WA  Aberdeen  Grays Harbor
# 5090   2017-05-31     35514          Hoquiam    WA  Aberdeen  Grays Harbor
# 9401   2017-05-31     33215     Ocean Shores    WA  Aberdeen  Grays Harbor
# 9149   2017-05-31     18370         Grayland    WA  Aberdeen  Grays Harbor
# 2073   2017-05-31     30116         Aberdeen    WA  Aberdeen  Grays Harbor
# 9859   2017-05-31     31062       Cosmopolis    WA  Aberdeen  Grays Harbor
# 4568   2017-05-31     56078        Montesano    WA  Aberdeen  Grays Harbor
# 8420   2017-05-31     19269         McCleary    WA  Aberdeen  Grays Harbor
# 7108   2017-05-31      6275         Oakville    WA  Aberdeen  Grays Harbor
# 10535  2017-05-31     54766          Tuscola    TX   Abilene        Taylor
# ...

# %%
df.sort_values('RegionID', ascending= False) #inplace -> mutable
# Out:
#              Date  RegionID             RegionName State  \
# 1736   2017-05-31    737791      Town of Mansfield    CT
# 731    2017-05-31    737790               Eastvale    CA
# 10827  2017-05-31    737788        Lebanon Borough    NJ
# 413    2017-05-31    737787         San Tan Valley    AZ
# 9295   2017-05-31    737786          The Sea Ranch    CA
# 8209   2017-05-31    399307       Berwick Township    PA
# 3154   2017-05-31    399305       Swatara Township    PA
# 2813   2017-05-31    399300        Exeter Township    PA
# 741    2017-05-31    399297      Muskegon Township    MI
# 10001  2017-05-31    399293                 Covert    NY
# 2971   2017-05-31    399292      Whitpain Township    PA
# 6119   2017-05-31    399290     Sugarloaf Township    PA
# 6475   2017-05-31    399289          Penn Township    PA
# 2124   2017-05-31    399288     Allendale Township    MI
# 6881   2017-05-31    399287    Portsmouth Township    MI
# ...

# %%
df.sort_values(['RegionID', 'State']) 
# 판다스에서 동시에 여러개 쓸려면 리스트  
# 첫번째 값을 비교하다가 같으면 다음 컬럼값으로 비교
# Out:
#              Date  RegionID             RegionName State  \
# 3043   2017-05-31      3301               Aberdeen    NC
# 4159   2017-05-31      3304                Absecon    NJ
# 4986   2017-05-31      3305               Accokeek    MD
# 1762   2017-05-31      3310                    Ada    OK
# 3116   2017-05-31      3312            Adairsville    GA
# 10202  2017-05-31      3315                  Adams    TN
# 1136   2017-05-31      3319                Addison    IL
# 10569  2017-05-31      3322                   Addy    WA
# 8018   2017-05-31      3333               Ahwahnee    CA
# 622    2017-05-31      3334                  Aiken    SC
# 3261   2017-05-31      3344                 Albion    MI
# 8315   2017-05-31      3352             Alexandria    AL
# 10456  2017-05-31      3379                   Alta    CA
# 10537  2017-05-31      3403              Andalusia    IL
# 378    2017-05-31      3404               Anderson    SC
# ...

# %%
df.sort_values(by=['Metro', 'County', 'Zhvi'], ascending=[True, True, False])
# Out:
#              Date  RegionID     RegionName State     Metro        County  \
# 7108   2017-05-31      6275       Oakville    WA  Aberdeen  Grays Harbor
# 4568   2017-05-31     56078      Montesano    WA  Aberdeen  Grays Harbor
# 4996   2017-05-31     36873           Elma    WA  Aberdeen  Grays Harbor
# 8420   2017-05-31     19269       McCleary    WA  Aberdeen  Grays Harbor
# 9401   2017-05-31     33215   Ocean Shores    WA  Aberdeen  Grays Harbor
# 9859   2017-05-31     31062     Cosmopolis    WA  Aberdeen  Grays Harbor
# 9851   2017-05-31     48458       Westport    WA  Aberdeen  Grays Harbor
# 9149   2017-05-31     18370       Grayland    WA  Aberdeen  Grays Harbor
# 2073   2017-05-31     30116       Aberdeen    WA  Aberdeen  Grays Harbor
# 5090   2017-05-31     35514        Hoquiam    WA  Aberdeen  Grays Harbor
# 5653   2017-05-31     44657          Clyde    TX   Abilene      Callahan
# 8855   2017-05-31      8218          Baird    TX   Abilene      Callahan
# ...

# %%
df.sort_values('Metro', inplace= True)

# %%
df.sort_values('RegionID', axis=1) 
#열은 항상 비교가 되지만, 행과 비교는 에러가 날 수 있따 .
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-03617714dc4a> in <module>()
# ----> 1 df.sort_values('RegionID', axis=1)
#       2 #열은 항상 비교가 되지만, 행과 비교는 에러가 날 수 있따 .
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4419             by = by[0]
#    4420             k = self._get_label_or_level_values(by, axis=axis,
# -> 4421                                                 stacklevel=stacklevel)
#    4422
#    4423             if isinstance(ascending, (tuple, list)):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis, stacklevel)
#    1380             values = self.axes[axis].get_level_values(key)._values
#    1381         else:
# -> 1382             raise KeyError(key)
#    1383
# ...

# %%
df.sort_values('RegionID', inplace=True)

# %%
df.reset_index()
# Out:
#        index        Date  RegionID             RegionName State  \
# 0       3043  2017-05-31      3301               Aberdeen    NC
# 1       4159  2017-05-31      3304                Absecon    NJ
# 2       4986  2017-05-31      3305               Accokeek    MD
# 3       1762  2017-05-31      3310                    Ada    OK
# 4       3116  2017-05-31      3312            Adairsville    GA
# 5      10202  2017-05-31      3315                  Adams    TN
# 6       1136  2017-05-31      3319                Addison    IL
# 7      10569  2017-05-31      3322                   Addy    WA
# 8       8018  2017-05-31      3333               Ahwahnee    CA
# 9        622  2017-05-31      3334                  Aiken    SC
# 10      3261  2017-05-31      3344                 Albion    MI
# 11      8315  2017-05-31      3352             Alexandria    AL
# 12     10456  2017-05-31      3379                   Alta    CA
# 13     10537  2017-05-31      3403              Andalusia    IL
# ...

# %%
df
# Out:
#              Date  RegionID             RegionName State  \
# 3043   2017-05-31      3301               Aberdeen    NC
# 4159   2017-05-31      3304                Absecon    NJ
# 4986   2017-05-31      3305               Accokeek    MD
# 1762   2017-05-31      3310                    Ada    OK
# 3116   2017-05-31      3312            Adairsville    GA
# 10202  2017-05-31      3315                  Adams    TN
# 1136   2017-05-31      3319                Addison    IL
# 10569  2017-05-31      3322                   Addy    WA
# 8018   2017-05-31      3333               Ahwahnee    CA
# 622    2017-05-31      3334                  Aiken    SC
# 3261   2017-05-31      3344                 Albion    MI
# 8315   2017-05-31      3352             Alexandria    AL
# 10456  2017-05-31      3379                   Alta    CA
# 10537  2017-05-31      3403              Andalusia    IL
# 378    2017-05-31      3404               Anderson    SC
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#        index        Date  RegionID             RegionName State  \
# 0       3043  2017-05-31      3301               Aberdeen    NC
# 1       4159  2017-05-31      3304                Absecon    NJ
# 2       4986  2017-05-31      3305               Accokeek    MD
# 3       1762  2017-05-31      3310                    Ada    OK
# 4       3116  2017-05-31      3312            Adairsville    GA
# 5      10202  2017-05-31      3315                  Adams    TN
# 6       1136  2017-05-31      3319                Addison    IL
# 7      10569  2017-05-31      3322                   Addy    WA
# 8       8018  2017-05-31      3333               Ahwahnee    CA
# 9        622  2017-05-31      3334                  Aiken    SC
# 10      3261  2017-05-31      3344                 Albion    MI
# 11      8315  2017-05-31      3352             Alexandria    AL
# 12     10456  2017-05-31      3379                   Alta    CA
# 13     10537  2017-05-31      3403              Andalusia    IL
# ...

# %%
# resetindex는 drop = true -> 과거의 인덱스를 판다스는 가능한 안전한게 디폴트 옵션

# %%
df.reset_index(drop=True)
# Out:
#        index        Date  RegionID             RegionName State  \
# 0       3043  2017-05-31      3301               Aberdeen    NC
# 1       4159  2017-05-31      3304                Absecon    NJ
# 2       4986  2017-05-31      3305               Accokeek    MD
# 3       1762  2017-05-31      3310                    Ada    OK
# 4       3116  2017-05-31      3312            Adairsville    GA
# 5      10202  2017-05-31      3315                  Adams    TN
# 6       1136  2017-05-31      3319                Addison    IL
# 7      10569  2017-05-31      3322                   Addy    WA
# 8       8018  2017-05-31      3333               Ahwahnee    CA
# 9        622  2017-05-31      3334                  Aiken    SC
# 10      3261  2017-05-31      3344                 Albion    MI
# 11      8315  2017-05-31      3352             Alexandria    AL
# 12     10456  2017-05-31      3379                   Alta    CA
# 13     10537  2017-05-31      3403              Andalusia    IL
# ...

# %%
# loc는 인덱스 이름을 가져온다. reset index를 많이 사용해

# %%
df.filter()  # 기본값 다 있으면 실행되는거 아냐? 아! 3개 다 입력해주세요 뜨는구나
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-73e7f15d3f49> in <module>()
# ----> 1 df.filter()  # 기본값 다 있으면 실행되는거 아냐? 아! 3개 다 입력해주세요 뜨는구나
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in filter(self, items, like, regex, axis)
#    3911             return self.loc(axis=axis)[values]
#    3912         else:
# -> 3913             raise TypeError('Must pass either `items`, `like`, or `regex`')
#    3914
#    3915     def head(self, n=5):
#
# TypeError: Must pass either `items`, `like`, or `regex`

# %%
df.filter(items=['State','Metro'])  # 컬럼 뽑기, dict, attr, loc, iloc, filter
# Out:
#       State                           Metro
# 0        NC        Pinehurst-Southern Pines
# 1        NJ                   Atlantic City
# 2        MD                      Washington
# 3        OK                             Ada
# 4        GA                         Atlanta
# 5        TN                     Clarksville
# 6        IL                         Chicago
# 7        WA                         Spokane
# 8        CA                          Madera
# 9        SC                         Augusta
# 10       MI                    Battle Creek
# 11       AL                        Anniston
# 12       CA                      Sacramento
# 13       IL                       Davenport
# 14       SC                      Greenville
# 15       TN                       Knoxville
# 16       IN                          Angola
# 17       AZ                         Phoenix
# 18       FL                           Ocala
# 19       MN             Minneapolis-St Paul
# ...

# %%
filterd_data = df.filter(regex='Region', axis=0)  #

# %%
filterd_data.head()
# Out:
# Empty DataFrame
# Columns: [index, Date, RegionID, RegionName, State, Metro, County, SizeRank, Zhvi]
# Index: []

# %%
filterd_data = df.filter(regex='Region', axis=1)  #
filterd_data.head()
# Out:
#    RegionID   RegionName
# 0      3301     Aberdeen
# 1      3304      Absecon
# 2      3305     Accokeek
# 3      3310          Ada
# 4      3312  Adairsville

# %%
df['Zhvi'] >50000 #결과값이 true false가 나온다.
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11       True
# 12       True
# 13       True
# 14       True
# 15       True
# 16       True
# 17       True
# 18       True
# 19       True
# 20       True
# 21       True
# 22       True
# 23       True
# 24       True
# 25       True
# 26       True
# 27       True
# 28       True
# 29       True
#          ...
# 10800    True
# 10801    True
# 10802    True
# 10803    True
# 10804    True
# 10805    True
# 10806    True
# 10807    True
# 10808    True
# 10809    True
# 10810    True
# 10811    True
# 10812    True
# 10813    True
# 10814    True
# 10815    True
# 10816    True
# 10817    True
# 10818    True
# 10819    True
# 10820    True
# 10821    True
# 10822    True
# 10823    True
# 10824    True
# 10825    True
# 10826    True
# 10827    True
# 10828    True
# 10829    True
# ...

# %%
 df[df.Zhvi >50000 ] #true인 값만 제출(filter방식)
# Out:
#        index        Date  RegionID             RegionName State  \
# 0       3043  2017-05-31      3301               Aberdeen    NC
# 1       4159  2017-05-31      3304                Absecon    NJ
# 2       4986  2017-05-31      3305               Accokeek    MD
# 3       1762  2017-05-31      3310                    Ada    OK
# 4       3116  2017-05-31      3312            Adairsville    GA
# 5      10202  2017-05-31      3315                  Adams    TN
# 6       1136  2017-05-31      3319                Addison    IL
# 7      10569  2017-05-31      3322                   Addy    WA
# 8       8018  2017-05-31      3333               Ahwahnee    CA
# 9        622  2017-05-31      3334                  Aiken    SC
# 10      3261  2017-05-31      3344                 Albion    MI
# 11      8315  2017-05-31      3352             Alexandria    AL
# 12     10456  2017-05-31      3379                   Alta    CA
# 13     10537  2017-05-31      3403              Andalusia    IL
# ...

# %%
df.filter(like='Met', axis=1) # like는 포함 하는 애
# Out:
#                                 Metro
# 0            Pinehurst-Southern Pines
# 1                       Atlantic City
# 2                          Washington
# 3                                 Ada
# 4                             Atlanta
# 5                         Clarksville
# 6                             Chicago
# 7                             Spokane
# 8                              Madera
# 9                             Augusta
# 10                       Battle Creek
# 11                           Anniston
# 12                         Sacramento
# 13                          Davenport
# 14                         Greenville
# 15                          Knoxville
# 16                             Angola
# 17                            Phoenix
# 18                              Ocala
# 19                Minneapolis-St Paul
# 20                       Philadelphia
# 21                           New York
# 22                          Worcester
# 23                             Dothan
# ...

# %%
#조건은 & 연결

# %%
df[(df['Zhvi'] > 1000000) & (df['State'] == 'NY')]
# Out:
#       index        Date  RegionID              RegionName State     Metro  \
# 805    9714  2017-05-31      7774              Water Mill    NY  New York
# 1694   6661  2017-05-31     12894              Muttontown    NY  New York
# 1886   3904  2017-05-31     13937             Southampton    NY  New York
# 2215   8093  2017-05-31     16387             Sands Point    NY  New York
# 2466   6736  2017-05-31     17874              East Hills    NY  New York
# 2557   1132  2017-05-31     18375              Great Neck    NY  New York
# 2572   3474  2017-05-31     18478                Harrison    NY  New York
# 2646   3064  2017-05-31     18955               Larchmont    NY  New York
# 2649   9028  2017-05-31     18963             Lattingtown    NY  New York
# 2794   9055  2017-05-31     19808         Oyster Bay Cove    NY  New York
# 3157   9370  2017-05-31     22015           Laurel Hollow    NY  New York
# 3748   3032  2017-05-31     25725               Manhasset    NY  New York
# ...

# %%
df[(df['Zhvi'] > 1000000) | (df['State'] == 'NY')]
# Out:
#        index        Date  RegionID             RegionName State  \
# 30      7720  2017-05-31      3509            Bal Harbour    FL
# 33      5375  2017-05-31      3521           Ballston Spa    NY
# 71     10205  2017-05-31      3734            Boca Grande    FL
# 91      8307  2017-05-31      3835             Brookhaven    NY
# 125     7328  2017-05-31      4028             Centerport    NY
# 144     7385  2017-05-31      4145             Clyde Hill    WA
# 173      757  2017-05-31      4281              Cupertino    CA
# 177    10786  2017-05-31      4313                 Dayton    NY
# 199     5753  2017-05-31      4482          East Moriches    NY
# 200     1581  2017-05-31      4484         East Northport    NY
# 201     7452  2017-05-31      4485           East Norwich    NY
# 299     8255  2017-05-31      4983              Greenport    NY
# 327     5931  2017-05-31      5137               Herricks    NY
# 340     4131  2017-05-31      5213                Hornell    NY
# ...

# %%
filter = df['Metro'].isin(['New York', 'SanFrancisco']) 
# in 하면 파이썬 in하고 충돌 되기 때문에 
df[filter].head() #filter에는 true
# Out:
#      index        Date  RegionID   RegionName State     Metro    County  \
# 21    2589  2017-05-31      3455  Asbury Park    NJ  New York  Monmouth
# 64     969  2017-05-31      3699   Bloomfield    NJ  New York     Essex
# 76    4075  2017-05-31      3752      Boonton    NJ  New York    Morris
# 91    8307  2017-05-31      3835   Brookhaven    NY  New York   Suffolk
# 125   7328  2017-05-31      4028   Centerport    NY  New York   Suffolk
#
#      SizeRank    Zhvi
# 21       2589  301300
# 64        969  316100
# 76       4075  380200
# 91       8307  362000
# 125      7328  502300

# %%
df['State'].unique()
# Out:
# array(['NC', 'NJ', 'MD', 'OK', 'GA', 'TN', 'IL', 'WA', 'CA', 'SC', 'MI',
#        'AL', 'IN', 'AZ', 'FL', 'MN', 'PA', 'MA', 'NY', 'OR', 'AR', 'TX',
#        'MO', 'WI', 'OH', 'NH', 'ID', 'VA', 'KY', 'CT', 'LA', 'WY', 'KS',
#        'CO', 'MS', 'ND', 'RI', 'UT', 'NE', 'HI', 'NV', 'AK', 'MT', 'IA',
#        'DE', 'WV', 'NM', 'DC', 'ME'], dtype=object)

# %%
df['State'].isin(['DC', 'PA'])
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20        True
# 21       False
# 22       False
# 23       False
# 24       False
# 25        True
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 10800    False
# 10801    False
# 10802     True
# 10803    False
# 10804     True
# 10805    False
# 10806    False
# 10807     True
# 10808     True
# 10809    False
# 10810    False
# 10811     True
# 10812    False
# 10813    False
# 10814    False
# 10815    False
# 10816    False
# 10817     True
# 10818     True
# 10819     True
# 10820    False
# 10821    False
# 10822     True
# 10823     True
# 10824     True
# 10825    False
# 10826    False
# ...

# %%
df[df['State'].isin(['DC', 'PA'])] #data의 행필터
# Out:
#        index        Date  RegionID                RegionName State  \
# 20      3101  2017-05-31      3436                   Ardmore    PA
# 25      7440  2017-05-31      3465                    Ashley    PA
# 47      4220  2017-05-31      3618                  Bellevue    PA
# 57      3636  2017-05-31      3649                   Berwick    PA
# 68      2804  2017-05-31      3706                Bloomsburg    PA
# 69      5302  2017-05-31      3711                 Blue Bell    PA
# 90      8237  2017-05-31      3831                  Brockway    PA
# 136     9462  2017-05-31      4106              Clarks Green    PA
# 137     5708  2017-05-31      4107             Clarks Summit    PA
# 205     1653  2017-05-31      4502                    Easton    PA
# 230     6801  2017-05-31      4615                      Etna    PA
# 252     4012  2017-05-31      4727                 Fleetwood    PA
# 256     7178  2017-05-31      4745                 Ford City    PA
# ...

# %%
1 in [1, 2, 3]
# Out:
# True

# %%
df[df.isin({'State': ['CA'], 'Metro': ['San Francisco']})] #nan이 나오네 
df[] # 조건에 맞는 행 뽑기
df[df.State == 'CA'] # true or false 나오기 # true만 나온다 
df[True] # 조거이 아니니깐 
df['State'].isin(['DC', 'PA']) # series type  # true false로 구성
df[ df['State'].isin(['DC', 'PA']) ]

#isin은 여러개 dict포맷
df.isin({'State': ['CA'], 'Metro': ['San Francisco']}) # dataframe의 조건을 넣었기 때문에 dataframe


#dict -> colum (컴럼이 하나면 시리즈 , 컬럼이 2개 이상이면 데이터프레임)
df.columns
df['Date'] # 시리즈
df[['Date']] # 데이터 프레임
# attr -> 무조건 시리즈 
# loc -> ,없이 나오면 행(전체의 열 다 ) -> 데이터 프레임
# 전체열 뽑든데 한 개만 뽑으면 시리즈 
df.loc[1:3,"Date"] # 시리즈 
df.loc[1:3,["Date"]] # 데이터프래임
# 시리즈 데이터프레임 가각 쓰이는 메서드가 다르다 
# iloc -> data frame or series


df[조건] # -> 참인것만 불러온다 
# $ -> 한 컬럼에서만 조건을 여러개 붙일 때
# 각각 컬럼에 조건을 줄 때 , dict 방식 
df[df.isin({'State': ['CA'], 'Metro': ['San Francisco']})] #nan이 나오네 ????????
