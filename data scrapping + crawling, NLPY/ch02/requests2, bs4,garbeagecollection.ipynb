# %%
import requests #http관련된 것 4가지 방법

# %%
data = response = requests.get("http://www.daum.net")

# %%
type(data)
# Out:
# requests.models.Response

# %%
dir(data)
# Out:
# ['__attrs__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_content',
#  '_content_consumed',
#  '_next',
#  'apparent_encoding',
#  'close',
#  'connection',
#  'content',
#  'cookies',
#  'elapsed',
#  'encoding',
#  'headers',
#  'history',
#  'is_permanent_redirect',
#  'is_redirect',
#  'iter_content',
#  'iter_lines',
#  'json',
#  'links',
#  'next',
#  'ok',
#  'raise_for_status',
#  'raw',
#  'reason',
#  'request',
#  'status_code',
#  'text',
#  'url']

# %%
data.content # 앞에 b가 있으면 byte(8bit) 브라우저 리스펀즈를 안해줘서
# Out:
# b'<!DOCTYPE html>\n<html lang="ko" class="">\n<head>\n<meta charset="utf-8"/>\n<title>Daum</title>\n<meta property="og:url" content="https://www.daum.net/">\n<meta property="og:type" content="website">\n<meta property="og:title" content="Daum">\n<meta property="og:image" content="//i1.daumcdn.net/svc/image/U03/common_icon/5587C4E4012FCD0001">\n<meta property="og:description" content="\xeb\x82\x98\xec\x9d\x98 \xea\xb4\x80\xec\x8b\xac \xec\xbd\x98\xed\x85\x90\xec\xb8\xa0\xeb\xa5\xbc \xea\xb0\x80\xec\x9e\xa5 \xec\xa6\x90\xea\xb2\x81\xea\xb2\x8c \xeb\xb3\xbc \xec\x88\x98 \xec\x9e\x88\xeb\x8a\x94 Daum">\n<meta name="msapplication-task" content="name=Daum;action-uri=https://www.daum.net/;icon-uri=/favicon.ico">\n<meta name="msapplication-task" content="name=\xeb\xaf\xb8\xeb\x94\x94\xec\x96\xb4\xeb\x8b\xa4\xec\x9d\x8c;action-uri=http://media.daum.net/;icon-uri=/media_favicon.ico">\n<meta name="msapplication-task" content="name=\xeb\xa9\x94\xec\x9d\xbc;action-uri=http://mail.daum.net;icon-ur
# ...

# %%
data.text # str
# Out:
# '<!DOCTYPE html>\n<html lang="ko" class="">\n<head>\n<meta charset="utf-8"/>\n<title>Daum</title>\n<meta property="og:url" content="https://www.daum.net/">\n<meta property="og:type" content="website">\n<meta property="og:title" content="Daum">\n<meta property="og:image" content="//i1.daumcdn.net/svc/image/U03/common_icon/5587C4E4012FCD0001">\n<meta property="og:description" content="나의 관심 콘텐츠를 가장 즐겁게 볼 수 있는 Daum">\n<meta name="msapplication-task" content="name=Daum;action-uri=https://www.daum.net/;icon-uri=/favicon.ico">\n<meta name="msapplication-task" content="name=미디어다음;action-uri=http://media.daum.net/;icon-uri=/media_favicon.ico">\n<meta name="msapplication-task" content="name=메일;action-uri=http://mail.daum.net;icon-uri=/mail_favicon.ico">\n<meta name="referrer" content="origin">\n<link rel="search" type="application/opensearchdescription+xml" href="//search.daum.net/OpenSearch.xml" title="다음">\n<style type="text/css">\n@charset "utf-8";\nbody,div,dl,dt,dd,ul,ol,li,h1,h2,h3,h4,h
# ...

# %%
# regular expresion
# beautifulsoup -> xml 처리
# beautifulsoup + lxml -> 속도가 빨라 (C libraryr) -> xml 처리  
# ** xml 파싱은 xpath 방식으로 (표준 방식)  <- 필요한 부분만 가져온다 scraping parsing; 정규식 i
#  response
# .content
# .text
# .json

# %%
'문근영' in data.text # 우아하지 않아 그래서  beautifulsoup  or lxml
# Out:
# False

# %%
html = requests.get("http://openapi.airkorea.or.kr/openapi/services/rest/ArpltnInforInqireSvc/getCtprvnMesureSidoLIst?serviceKey=C9N9ExnIbd5esuobQ8zjDOi5p3iWoDQOhCRSlvgi4%2BgQEeLhRR4K3hDf%2BG3W%2BrZULxTVB3qUCrTxcAE43A6VNA%3D%3D&numOfRows=10&pageSize=10&pageNo=1&startPage=1&sidoName=%EC%84%9C%EC%9A%B8&searchCondition=DAILY")

# %%
print(html.text)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
#
#
#
#
# <response>
# 	<header>
# 		<resultCode>00</resultCode>
# 		<resultMsg>NORMAL SERVICE.</resultMsg>
# 	</header>
# 	<body>
# 		<items>
#
# 				<item>
# 				    <dataTime>2018-07-21 16:00</dataTime>
# 				    <cityName>강남구</cityName>
# 				    <so2Value>0.008</so2Value>
# 				    <coValue>0.5</coValue>
# 				    <o3Value>0.139</o3Value>
# 				    <no2Value>0.029</no2Value>
# 				    <pm10Value>59</pm10Value>
# 				    <pm25Value>52</pm25Value>
# 				</item>
#
# 				<item>
# 				    <dataTime>2018-07-21 16:00</dataTime>
# 				    <cityName>강동구</cityName>
# 				    <so2Value>0.005</so2Value>
# 				    <coValue>0.5</coValue>
# 				    <o3Value>0.117</o3Value>
# 				    <no2Value>0.023</no2Value>
# 				    <pm10Value>50</pm10Value>
# 				    <pm25Value>40</pm25Value>
# 				</item>
#
# 				<item>
# 				    <dataTime>2018-07-21 16:00</dataTime>
# 				    <cityName>강북구</cityName>
# 				    <so2Value>0.004</so2Value>
# ...

# %%
from bs4 import BeautifulSoup

# %%
data = BeautifulSoup(data.text)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\ProgramData\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
data = BeautifulSoup(html.text, "lxml")

# %%
type(data)
# Out:
# bs4.BeautifulSoup

# %%
dir(data)
# Out:
# ['ASCII_SPACES',
#  'DEFAULT_BUILDER_FEATURES',
#  'HTML_FORMATTERS',
#  'NO_PARSER_SPECIFIED_WARNING',
#  'ROOT_TAG_NAME',
#  'XML_FORMATTERS',
#  '__bool__',
#  '__call__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_all_strings',
#  '_attr_value_as_string',
#  '_attribute_checker',
#  '_check_markup_is_url',
#  '_feed',
#  '_find_all',
#  '_find_one',
#  '_formatter_for_name',
#  '_is_xml',
#  '_lastRecursiveChild',
# ...

# %%
data
# Out:
# <?xml version="1.0" encoding="UTF-8"?><html><body><response>
# <header>
# <resultcode>00</resultcode>
# <resultmsg>NORMAL SERVICE.</resultmsg>
# </header>
# <items>
# <item>
# <datatime>2018-07-21 16:00</datatime>
# <cityname>강남구</cityname>
# <so2value>0.008</so2value>
# <covalue>0.5</covalue>
# <o3value>0.139</o3value>
# <no2value>0.029</no2value>
# <pm10value>59</pm10value>
# <pm25value>52</pm25value>
# </item>
# <item>
# <datatime>2018-07-21 16:00</datatime>
# <cityname>강동구</cityname>
# <so2value>0.005</so2value>
# <covalue>0.5</covalue>
# <o3value>0.117</o3value>
# <no2value>0.023</no2value>
# <pm10value>50</pm10value>
# <pm25value>40</pm25value>
# </item>
# <item>
# <datatime>2018-07-21 16:00</datatime>
# <cityname>강북구</cityname>
# <so2value>0.004</so2value>
# <covalue>0.3</covalue>
# <o3value>0.106</o3value>
# <no2value>0.012</no2value>
# <pm10value>34</pm10value>
# <pm25value>22</pm25value>
# </item>
# <item>
# <datatime>2018-07-21 16:00</datatime>
# <cityname>강서구</cityname>
# ...

# %%
parsed = data.findAll("item")

# %%
parsed
# Out:
# [<item>
#  <datatime>2018-07-21 16:00</datatime>
#  <cityname>강남구</cityname>
#  <so2value>0.008</so2value>
#  <covalue>0.5</covalue>
#  <o3value>0.139</o3value>
#  <no2value>0.029</no2value>
#  <pm10value>59</pm10value>
#  <pm25value>52</pm25value>
#  </item>, <item>
#  <datatime>2018-07-21 16:00</datatime>
#  <cityname>강동구</cityname>
#  <so2value>0.005</so2value>
#  <covalue>0.5</covalue>
#  <o3value>0.117</o3value>
#  <no2value>0.023</no2value>
#  <pm10value>50</pm10value>
#  <pm25value>40</pm25value>
#  </item>, <item>
#  <datatime>2018-07-21 16:00</datatime>
#  <cityname>강북구</cityname>
#  <so2value>0.004</so2value>
#  <covalue>0.3</covalue>
#  <o3value>0.106</o3value>
#  <no2value>0.012</no2value>
#  <pm10value>34</pm10value>
#  <pm25value>22</pm25value>
#  </item>, <item>
#  <datatime>2018-07-21 16:00</datatime>
#  <cityname>강서구</cityname>
#  <so2value>0.013</so2value>
#  <covalue>0.3</covalue>
#  <o3value>0.106</o3value>
#  <no2value>0.016</no2value>
# ...

# %%
len(parsed)
# Out:
# 10

# %%
for i,j in enumerate(parsed):
    print(i,j)
    print(j.pm10value) # 객체로 구성되어있기 때문에 dot notation으로 사용 
    print(j.pm10value.text)
    #named tuple
    
    # persist 유지가 안됨-> 데이터를 파일을 만들어서 저장 
    # rdb로 변환시켜서 splite 파싱해서 집어넣어 
    # 디비 하나만 있으면 끝 dump 
    # lxml or html.parser
# Out:
# 0 <item>
# <datatime>2018-07-21 16:00</datatime>
# <cityname>강남구</cityname>
# <so2value>0.008</so2value>
# <covalue>0.5</covalue>
# <o3value>0.139</o3value>
# <no2value>0.029</no2value>
# <pm10value>59</pm10value>
# <pm25value>52</pm25value>
# </item>
# <pm10value>59</pm10value>
# 59
# 1 <item>
# <datatime>2018-07-21 16:00</datatime>
# <cityname>강동구</cityname>
# <so2value>0.005</so2value>
# <covalue>0.5</covalue>
# <o3value>0.117</o3value>
# <no2value>0.023</no2value>
# <pm10value>50</pm10value>
# <pm25value>40</pm25value>
# </item>
# <pm10value>50</pm10value>
# 50
# 2 <item>
# <datatime>2018-07-21 16:00</datatime>
# <cityname>강북구</cityname>
# <so2value>0.004</so2value>
# <covalue>0.3</covalue>
# <o3value>0.106</o3value>
# <no2value>0.012</no2value>
# <pm10value>34</pm10value>
# <pm25value>22</pm25value>
# </item>
# <pm10value>34</pm10value>
# 34
# 3 <item>
# <datatime>2018-07-21 16:00</datatime>
# <cityname>강서구</cityname>
# <so2value>0.013</so2value>
# <covalue>0.3</covalue>
# ...

# %%
#db로 넣어오기 
# 1. 인자

# %%
# %%writefile moon.txt
# 문근영님!!
# 사랑해용!!!
# Out:
# Overwriting moon.txt

# %%
# 파일객체를 연결 시키기 위해서 
# 문을 열어줘야해 open 
f = open('moon.txt', 'r', encoding= "utf-8") # read r write a apend a 
type(f) # iter
# Out:
# _io.TextIOWrapper

# %%
for i in f:
    print(i, end="")
    # 두번 실행하면 안나옴 generater (lazy기법)

# %%
# 파이썬 특정 문자는 행나눔

# %%
a = (x for x in range(5))

# %%
next(a)
# Out:
# 1

# %%
files = []
for i in range(100000):
    files.append(open('moon.txt')) #OSError (컴퓨터에서 열 수 있는 파일 수가 정해짐)
                                    # 파일을 열어주면 항상 닫아주지만, 자동으로 가비지 컬렉션이 된다. 
                                    # 한꺼번에 열어준 케이스
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-7-e33be9ab9e4a> in <module>()
#       1 files = []
#       2 for i in range(100000):
# ----> 3     files.append(open('moon.txt')) #OSError (컴퓨터에서 열 수 있는 파일 수가 정해짐)
#       4                                     # 파일을 열어주면 항상 닫아주지만, 자동으로 가비지 컬렉션이 된다.
#       5                                     # 한꺼번에 열어준 케이스
#
# OSError: [Errno 24] Too many open files: 'moon.txt'

# %%
with open('moon.txt') as f:
    print(f.read())
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-50-f1300f403232> in <module>()
# ----> 1 with open('moon.txt') as f:
#       2     print(f.read())
#       3
#
# OSError: [Errno 24] Too many open files: 'moon.txt'

# %%
# __ enter __ 와 __exit__가 존재할 시 read를 할 수 있다. 
# 아니면 오버라이딩

# %%
# 과제
# url집어넣는거 함수형태로 만들어서 바꿀 수 있게 (인자 넣을 때)
# 데이터를 가져와서 sqllite로 넘기는것 
# 몽고디비로 넘겨두 되는디
