# %%
import builtwith

# %%
# !pip install builtwith
# Out:
# ...
#   Running setup.py bdist_wheel for builtwith: started
#   Running setup.py bdist_wheel for builtwith: finished with status 'done'
#   Stored in directory: C:\Users\cheerup\AppData\Local\pip\Cache\wheels\2b\00\c2\a96241e7fe520e75093898bf926764a924873e0304f10b2524
# Successfully built builtwith
# ...
# tensorflow-gpu 1.7.0 has requirement tensorboard<1.8.0,>=1.7.0, but you'll have tensorboard 1.8.0 which is incompatible.

# %%
#상대방 웹서버 확인
# Out:
# 명령 구문이 올바르지 않습니다.

# %%
import builtwith

# %%
builtwith.parse("http://www.google.com")
# Out:
# {'web-servers': ['Google Web Server']}

# %%
builtwith.parse("http://www.naver.com")
# Out:
# {}

# %%
builtwith.parse("http://www.wordpress.com")
# Out:
# {'blogs': ['PHP', 'WordPress'],
#  'cms': ['WordPress'],
#  'ecommerce': ['WooCommerce'],
#  'font-scripts': ['Google Font API'],
#  'programming-languages': ['PHP'],
#  'web-servers': ['Nginx']}

# %%
builtwith.parse("http://www.daum.net")
# Out:
# {}

# %%
# !pip install whois

# %%
import whois

# %%
dir(whois)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EnvironmentError',
#  'Exception',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NICClient',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
#  'PermissionError',
#  'ProcessLookupError',
# ...

# %%
whois.whois("naver.com")
# Out:
# {'address': '6 Buljung-ro, Bundang-gu, Seongnam-si, Gyeonggi-do, 463-867, Korea',
#  'city': 'Gyeonggi',
#  'country': 'KR',
#  'creation_date': [datetime.datetime(1997, 9, 12, 4, 0),
#   datetime.datetime(1997, 9, 12, 0, 0)],
#  'dnssec': 'unsigned',
#  'domain_name': ['NAVER.COM', 'naver.com'],
#  'emails': ['white.4818@navercorp.com',
#   'dl_ssl@navercorp.com',
#   'abuse@gabia.com'],
#  'expiration_date': [datetime.datetime(2023, 9, 11, 4, 0),
#   datetime.datetime(2023, 9, 11, 0, 0)],
#  'name': 'NAVER Corp.',
#  'name_servers': ['NS1.NAVER.COM',
#   'NS2.NAVER.COM',
#   'ns1.naver.com',
#   'ns2.naver.com'],
#  'org': 'NAVER Corp.',
#  'referral_url': None,
#  'registrar': 'Gabia, Inc.',
#  'state': None,
#  'status': ['clientDeleteProhibited https://icann.org/epp#clientDeleteProhibited',
#   'clientTransferProhibited https://icann.org/epp#clientTransferProhibited',
#   'clientUpdateProhibited https://icann.org/epp#clientUpdateProhibited',
#   'ok https://icann.org/epp#ok'],
# ...

# %%
whois.whois("appspot.com")
# Out:
# {'address': None,
#  'city': None,
#  'country': 'US',
#  'creation_date': [datetime.datetime(2005, 3, 10, 2, 27, 55),
#   datetime.datetime(2005, 3, 9, 18, 27, 55)],
#  'dnssec': 'unsigned',
#  'domain_name': ['APPSPOT.COM', 'appspot.com'],
#  'emails': ['abusecomplaints@markmonitor.com', 'whoisrelay@markmonitor.com'],
#  'expiration_date': [datetime.datetime(2019, 3, 10, 1, 27, 55),
#   datetime.datetime(2019, 3, 9, 0, 0)],
#  'name': None,
#  'name_servers': ['NS1.GOOGLE.COM',
#   'NS2.GOOGLE.COM',
#   'NS3.GOOGLE.COM',
#   'NS4.GOOGLE.COM',
#   'ns2.google.com',
#   'ns1.google.com',
#   'ns3.google.com',
#   'ns4.google.com'],
#  'org': 'Google LLC',
#  'referral_url': None,
#  'registrar': 'MarkMonitor, Inc.',
#  'state': 'CA',
#  'status': ['clientDeleteProhibited https://icann.org/epp#clientDeleteProhibited',
#   'clientTransferProhibited https://icann.org/epp#clientTransferProhibited',
#   'clientUpdateProhibited https://icann.org/epp#clientUpdateProhibited',
# ...

# %%
whois.whois("ini.korea.ac.kr")
# Out:
# {'admin_email': 'security@korea.ac.kr',
#  'admin_name': 'korea university',
#  'admin_phone': '02-3290-4193',
#  'creation_date': datetime.datetime(1993, 8, 2, 0, 0),
#  'domain_name': 'korea.ac.kr',
#  'expiration_date': datetime.datetime(2019, 10, 15, 0, 0),
#  'name_servers': ['kuccgx.korea.ac.kr', 'kucc.korea.ac.kr'],
#  'registrant_address': 'Anam-dong 5(o)-ga, Seongbuk-gu, Seoul, Republic of Korea, Anam-dong 5-ga, Seongbuk-gu, Seoul KR',
#  'registrant_org': 'korea university',
#  'registrant_zip': '136701',
#  'registrar': 'Inames Co., Ltd.(http://www.inames.co.kr)',
#  'updated_date': datetime.datetime(2015, 5, 29, 0, 0)}

# %%
from urllib.request import urlopen

# %%
req = urlopen("http://python.org")

# %%
type(req.read()) # string 타입으로 바꿔줘야한디
# Out:
# bytes

# %%
text = req.read().decode("utf-8")

# %%
text
# Out:
# ''

# %%
resp = urlopen("https://www.google.co.kr/search?q=%ED%95%9C%EA%B8%80&oq=%ED%95%9C%EA%B8%80&aqs=chrome..69i57j69i65j35i39j0l3.4508j0j4&sourceid=chrome&ie=UTF-8")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-17-d9508e122557> in <module>()
# ----> 1 resp = urlopen("https://www.google.co.kr/search?q=%ED%95%9C%EA%B8%80&oq=%ED%95%9C%EA%B8%80&aqs=chrome..69i57j69i65j35i39j0l3.4508j0j4&sourceid=chrome&ie=UTF-8")
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# ...

# %%
# serach는 disable 허락 하지 않아서 
# 정상적인 사용자라고 인식하지 않았기 때문에 
# 강제로 접속하는것을 보고 막았다....

# %%
resp.read()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-2948571ce85a> in <module>()
# ----> 1 resp.read()
#
# NameError: name 'resp' is not defined

# %%
resp = urlopen("https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query=%ED%95%9C%EA%B8%80")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-20-ef473bc7f5a7> in <module>()
# ----> 1 resp = urlopen("https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query=%ED%95%9C%EA%B8%80")
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# ...

# %%
# 400대 에러는 사용자의 잘못 
# header 정보가 없기 때문에 사용자라고 인식을 안한다 .

# %%
from urllib.error import HTTPError

# %%
try:
    resp = urlopen("https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query=%ED%95%9C%EA%B8%80")    
except HTTPError as e:
    print (e.code, e.reason, e.headers)
# Out:
# 403 Forbidden Date: Thu, 19 Jul 2018 16:59:59 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: close
# Vary: Accept-Encoding
# Set-Cookie: page_uid=T1vvBwpVuERssZK44N0ssssstUw-503542; path=/; domain=.naver.com
# Set-Cookie: _naver_usersession_=zY5aX6+mmr3erUrBaHGWDw==; path=/; expires=Thu, 19-Jul-18 17:04:59 GMT; domain=.naver.com
# X-Frame-Options: SAMEORIGIN
# X-XSS-Protection: 1; report=/p/er/post/xss
# Cache-Control: no-cache, no-store, must-revalidate, max-age=0
# Pragma: no-cache
# Vary: Accept-Encoding

# %%
# 500대 에러는 서버에서 잘못 다시 요청 
# 너무 많은 요청 반복은 피하자 
# api는 키값을 받았으므로 헤더가 필요없다.

# %%
from urllib.request import Request
from urllib.error import HTTPError

def download(url, agent="python bot",num_retries = 2 ):
    # 패킷 만들기
    headers = {"User-agent":agent}
    req = Request(url, headers= headers)
    
    try:
        resp = urlopen(req)
        
    except HTTPError as e:
        resp = None
        print (e.code, e.reason, e.headers)
        
        if 500<= e.code <=600 and num_retries > 0:
            return download(url, num_retries=num_retries-1)
    
    return resp

# %%
html = download("http://httpstat.us/500")
# Out:
# 500 Internal Server Error Cache-Control: private
# Server: Microsoft-IIS/10.0
# X-AspNetMvc-Version: 5.1
# Access-Control-Allow-Origin: *
# X-AspNet-Version: 4.0.30319
# X-Powered-By: ASP.NET
# Set-Cookie: ARRAffinity=8d9742d8920fc8f87dbfb6e900a1f176e365d58296d2c5e44961e07bf1b65817;Path=/;HttpOnly;Domain=httpstat.us
# Date: Thu, 19 Jul 2018 17:00:57 GMT
# Connection: close
# Content-Length: 0
#
#
# 500 Internal Server Error Cache-Control: private
# Server: Microsoft-IIS/10.0
# X-AspNetMvc-Version: 5.1
# Access-Control-Allow-Origin: *
# X-AspNet-Version: 4.0.30319
# X-Powered-By: ASP.NET
# Set-Cookie: ARRAffinity=8d9742d8920fc8f87dbfb6e900a1f176e365d58296d2c5e44961e07bf1b65817;Path=/;HttpOnly;Domain=httpstat.us
# Date: Thu, 19 Jul 2018 17:00:58 GMT
# Connection: close
# Content-Length: 0
#
#
# 500 Internal Server Error Cache-Control: private
# Server: Microsoft-IIS/10.0
# X-AspNetMvc-Version: 5.1
# Access-Control-Allow-Origin: *
# X-AspNet-Version: 4.0.30319
# X-Powered-By: ASP.NET
# ...

# %%
html = download("https://www.google.com/search?source=hp&ei=lyFMW-DqLdXQ8wXTgLmYBw&q=%ED%95%9C%EA%B8%80&oq=%ED%95%9C%EA%B8%80&gs_l=psy-ab.3..35i39k1l2j0l3j0i131k1j0l4.887.2320.0.2617.11.9.0.0.0.0.235.957.0j4j1.6.0....0...1.1j4.64.psy-ab..7.4.762.6..0i10i42k1j0i10k1j0i20i263k1.140.fBOmsznnNOs")

# %%
agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.99 Safari/537.36"
html = download("https://www.google.com/search?source=hp&ei=lyFMW-DqLdXQ8wXTgLmYBw&q=%ED%95%9C%EA%B8%80&oq=%ED%95%9C%EA%B8%80&gs_l=psy-ab.3..35i39k1l2j0l3j0i131k1j0l4.887.2320.0.2617.11.9.0.0.0.0.235.957.0j4j1.6.0....0...1.1j4.64.psy-ab..7.4.762.6..0i10i42k1j0i10k1j0i20i263k1.140.fBOmsznnNOs", agent=agent)

# %%
html.read().decode("utf-8")
# Out:
# '<!doctype html><html itemscope="" itemtype="http://schema.org/SearchResultsPage" lang="ko"><head><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><link href="/images/branding/product/ico/googleg_lodp.ico" rel="shortcut icon"><meta content="origin" name="referrer"><title>한글 - Google 검색</title><script nonce="lPaYvy3jeqRBQv17iKEhlw==">(function(){window.google={kEI:\'-cNQW8TXIouK8wWZy4yQAg\',kEXPI:\'31\',authuser:0,kscs:\'c9c918f0_-cNQW8TXIouK8wWZy4yQAg\',kGL:\'KR\'};google.kHL=\'ko\';})();google.time=function(){return(new Date).getTime()};google.timers={};google.startTick=function(c,b){var a=b&&google.timers[b].t?google.timers[b].t.start:google.time();google.timers[c]={t:{start:a},e:{},m:{}};(a=window.performance)&&a.now&&(google.timers[c].wsrt=Math.floor(a.now()))};google.startTick("webaft");google.startTick("load");</script><!--srt--><script nonce="lPaYvy3jeqRBQv17iKEhlw==">(function(){google.lc=[];google.li=0;google.getEI=function(a){for
# ...

# %%
# post => 데이터가 많을 때 서버 작업이 많을 때 (직렬화 (바이트로 바꾸어서, server에서는 자동으로 변환 ))
# get => 
# 회원가입 (중요하고 서버에서 처리해야하는건 post, 물론 get으로 사용할 수 있어 )

# %%
import requests

def download(url, agent="python bot",num_retries = 2 ):
    # 패킷 만들기
    headers = {"User-agent":agent}
    resp = requests.request("get",url, headers= headers) #abstraciton 
    
 
    if 500<= resp.status_code <=600 and num_retries > 0:
        print (resp.status_code, resp.reason)
        return download(url, num_retries=num_retries-1)

    
    return resp

# %%
agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.99 Safari/537.36"
html = download("https://www.google.com/search?source=hp&ei=lyFMW-DqLdXQ8wXTgLmYBw&q=%ED%95%9C%EA%B8%80&oq=%ED%95%9C%EA%B8%80&gs_l=psy-ab.3..35i39k1l2j0l3j0i131k1j0l4.887.2320.0.2617.11.9.0.0.0.0.235.957.0j4j1.6.0....0...1.1j4.64.psy-ab..7.4.762.6..0i10i42k1j0i10k1j0i20i263k1.140.fBOmsznnNOs", agent=agent)

# %%
type(html.text) #str 해석
# Out:
# str

# %%
html.encoding # 자동으로 utf-8로 디폴트 되어 있음 #해외사이트에서 깨질 수 도 있어서 주의
# Out:
# 'UTF-8'

# %%
from urllib import parse

# %%
parse.quote("한글") # 지덩으로 hex byte로 변환
# Out:
# '%ED%95%9C%EA%B8%80'

# %%
url="http://www.google.co.kr/search?q="+parse.quote("고려대")+"&aqs=chrome..69i57j69i60l2j69i65j35i39j0.2173j0j7&sourceid=chrome&ie=UTF-8"

# %%
agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.99 Safari/537.36"
html = download(url, agent=agent)

# %%
html.read().decode("utf-8")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-8afb516e23b0> in <module>()
# ----> 1 html.read().decode("utf-8")
#
# AttributeError: 'Response' object has no attribute 'read'

# %%
html.text
# Out:
# '<!doctype html><html itemscope="" itemtype="http://schema.org/SearchResultsPage" lang="ko"><head><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><link href="/images/branding/product/ico/googleg_lodp.ico" rel="shortcut icon"><meta content="origin" name="referrer"><title>고려대 - Google 검색</title><script nonce="QtyLI3V61/odQHhmGXvwVQ==">(function(){window.google={kEI:\'XsRQW42qMora8wXdn7uQCw\',kEXPI:\'31\',authuser:0,kscs:\'c9c918f0_XsRQW42qMora8wXdn7uQCw\',kGL:\'KR\'};google.kHL=\'ko\';})();google.time=function(){return(new Date).getTime()};google.timers={};google.startTick=function(c,b){var a=b&&google.timers[b].t?google.timers[b].t.start:google.time();google.timers[c]={t:{start:a},e:{},m:{}};(a=window.performance)&&a.now&&(google.timers[c].wsrt=Math.floor(a.now()))};google.startTick("webaft");google.startTick("load");</script><!--srt--><script nonce="QtyLI3V61/odQHhmGXvwVQ==">(function(){google.lc=[];google.li=0;google.getEI=function(a){fo
# ...

# %%
import json

# %%
params ={
        "where":"nexearch",
        "sm":"top_hty",
         "fbm":1,
         "ie":"utf-8",
         "query":parse.quote("고려대")
         
        }

# %%
jsonParam = json.dumps(params)

# %%
jsonParam
# Out:
# '{"where": "nexearch", "sm": "top_hty", "fbm": 1, "ie": "utf-8", "query": "%EA%B3%A0%EB%A0%A4%EB%8C%80"}'

# %%
import requests

def downloadJson(url, agent="python bot",num_retries = 2 ):
    # 패킷 만들기
    headers = {"User-agent":agent}
    resp = requests.request("post",url, headers= headers, json=jsonParam ) #abstraciton 
    
 
    if 500<= resp.status_code <=600 and num_retries > 0:
        print (resp.status_code, resp.reason)
        return download(url, num_retries=num_retries-1)

    
    return resp

# %%
html = downloadJson("http://httpbin.org/post")

# %%
html.text
# Out:
# '{"args":{},"data":"\\"{\\\\\\"where\\\\\\": \\\\\\"nexearch\\\\\\", \\\\\\"sm\\\\\\": \\\\\\"top_hty\\\\\\", \\\\\\"fbm\\\\\\": 1, \\\\\\"ie\\\\\\": \\\\\\"utf-8\\\\\\", \\\\\\"query\\\\\\": \\\\\\"%EA%B3%A0%EB%A0%A4%EB%8C%80\\\\\\"}\\"","files":{},"form":{},"headers":{"Accept":"*/*","Accept-Encoding":"gzip, deflate","Connection":"close","Content-Length":"123","Content-Type":"application/json","Host":"httpbin.org","User-Agent":"python bot"},"json":"{\\"where\\": \\"nexearch\\", \\"sm\\": \\"top_hty\\", \\"fbm\\": 1, \\"ie\\": \\"utf-8\\", \\"query\\": \\"%EA%B3%A0%EB%A0%A4%EB%8C%80\\"}","origin":"220.117.248.182","url":"http://httpbin.org/post"}\n'

# %%
import requests

def downloadGet(url, agent="python bot",num_retries = 2 ):
    # 패킷 만들기
    headers = {"User-agent":agent}
#     resp = requests.request("get",url, headers= headers) 
    resp = requests.get(url, headers=headers,params=params ) # json 파라미터 넘길거 아니니깐
    
 
    if 500<= resp.status_code <=600 and num_retries > 0:
        print (resp.status_code, resp.reason)
        return download(url, num_retries=num_retries-1)

    
    return resp

# %%
agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.99 Safari/537.36"
html = downloadGet("http://www.google.co.kr/search?q", agent=agent)

# %%
html.text
# Out:
# '<!doctype html><html itemscope="" itemtype="http://schema.org/SearchResultsPage" lang="ko"><head><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><link href="/images/branding/product/ico/googleg_lodp.ico" rel="shortcut icon"><meta content="origin" name="referrer"><title>%EA%B3%A0%EB%A0%A4%EB%8C%80 - Google 검색</title><script nonce="bpC03/K0dFrFdPK6nS79tA==">(function(){window.google={kEI:\'Bi5MW6mFF4_r-Qad44PwCQ\',kEXPI:\'31\',authuser:0,kscs:\'c9c918f0_Bi5MW6mFF4_r-Qad44PwCQ\',kGL:\'KR\'};google.kHL=\'ko\';})();google.time=function(){return(new Date).getTime()};google.timers={};google.startTick=function(c,b){var a=b&&google.timers[b].t?google.timers[b].t.start:google.time();google.timers[c]={t:{start:a},e:{},m:{}};(a=window.performance)&&a.now&&(google.timers[c].wsrt=Math.floor(a.now()))};google.startTick("webaft");google.startTick("load");</script><!--srt--><script nonce="bpC03/K0dFrFdPK6nS79tA==">(function(){google.lc=[];google.li=0;goo
# ...

# %%
# get
# 데이터 구조화 한것은 힘들다 다 바이트 형식으로 보내야하기 때문에 
# url 전체 
# crud 
# 여러가지 데이터 타입 보내기 힘들다. 
# 한글이 깨 질  수 있다 

# post f
# 데이터는 데이터대로 url은 url대로 보내느것
# 실제 데이터를 받아와 json ~ 어쩌국 
# 바이트로 해석 

# 많은양, 데이터타입 살리기, 보안  하고 싶을 때
