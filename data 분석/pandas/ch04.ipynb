# %%
import pandas as pd

# %%
df = pd.read_csv("apt_final.csv")

# %%
df
# Out:
#         price_per_area     price  con_year  year dong           aptnm  month  \
# 0                 1979   71000.0      1982  2009  개포동        개포주공 3단지     10
# 1                 1994   83700.0      1982  2009  개포동        개포주공 1단지     10
# 2                 1128  173500.0      2004  2009  개포동      개포자이(12-2)     10
# 3                 1204   65000.0      1983  2009  개포동        개포주공 5단지     10
# 4                 1214  160000.0      1986  2009  개포동             현대2     10
# 5                 1480   75000.0      1982  2009  개포동        개포주공 4단지     10
# 6                 1030   82000.0      1987  2009  개포동             우성8     10
# 7                 1275   78000.0      1983  2009  개포동        개포주공 5단지     10
# 8                 1975  100000.0      1982  2009  개포동        개포주공 1단지     10
# 9                 1133   44800.0      1992  2009  개포동      성원대치2단지아파트     10
# 10                1115   37000.0      1992  2009  개포동      성원대치2단지아파트     10
# ...

# %%
df.head()
# Out:
#    price_per_area     price  con_year  year dong       aptnm  month   dat  \
# 0            1979   71000.0      1982  2009  개포동    개포주공 3단지     10  1~10
# 1            1994   83700.0      1982  2009  개포동    개포주공 1단지     10  1~10
# 2            1128  173500.0      2004  2009  개포동  개포자이(12-2)     10  1~10
# 3            1204   65000.0      1983  2009  개포동    개포주공 5단지     10  1~10
# 4            1214  160000.0      1986  2009  개포동         현대2     10  1~10
#
#      area area_sub  ...   seoul_cons_ratio  bond_one_year bond_three_year  \
# 0   35.87    small  ...          10.061728           3.52            4.47
# 1   41.98    small  ...          10.061728           3.52            4.47
# 2  153.80    large  ...          10.061728           3.52            4.47
# 3   53.98    small  ...          10.061728           3.52            4.47
# 4  131.83    large  ...          10.061728           3.52            4.47
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 429466 entries, 0 to 429465
# Data columns (total 62 columns):
# price_per_area          429466 non-null int64
# price                   429466 non-null float64
# con_year                429466 non-null int64
# year                    429466 non-null int64
# dong                    429466 non-null object
# aptnm                   429466 non-null object
# month                   429466 non-null int64
# dat                     429466 non-null object
# area                    429466 non-null float64
# area_sub                429466 non-null object
# loc                     429466 non-null int64
# floor                   429466 non-null int64
# qrt                     429466 non-null object
# yyyyqrt                 429466 non-null object
# yyyym                   429466 non-null int64
# gu                      429466 non-null object
# num_children            429466 non-null int64
# num_elementary          429466 non-null int64
# ...

# %%
df.describe()
# Out:
#        price_per_area          price       con_year           year  \
# count   429466.000000  429466.000000  429466.000000  429466.000000
# mean       671.892266   52892.603109    1997.477384    2013.865475
# std        328.450378   36912.570766       9.403677       2.611333
# min         10.000000    1000.000000    1961.000000    2009.000000
# 25%        448.000000   30000.000000    1989.000000    2012.000000
# 50%        566.000000   42500.000000    1999.000000    2015.000000
# 75%        799.000000   63500.000000    2005.000000    2016.000000
# max       4223.000000  790000.000000    2017.000000    2017.000000
#
#                month           area            loc          floor  \
# count  429466.000000  429466.000000  429466.000000  429466.000000
# mean        6.451859      77.911301   11525.210832       8.713360
# std         3.251879      29.821640     164.825753       5.935531
# min         1.000000      10.321500   11110.000000      -4.000000
# ...

# %%
df.sample()
# Out:
#         price_per_area    price  con_year  year dong  aptnm  month    dat  \
# 312623             506  30000.0      1999  2016  공릉동  태강아파트     10  21~31
#
#          area area_sub  ...   seoul_cons_ratio  bond_one_year bond_three_year  \
# 312623  59.34    small  ...          11.374837           1.37            1.36
#
#        bond_five_year  bond_ten_year corp_bond_yield_rate  call_rate  \
# 312623           1.41            1.6                 1.78       1.23
#
#         interest  interest_on_loan   cd
# 312623      1.41              3.29  1.35
#
# [1 rows x 62 columns]

# %%
a = list( ["신사동", "압구정1동","압구정2동", "논현동","논현1동","논현2동", "청담동", "청담1동","청담2동", "삼성동","삼성1동","삼성2동","대치동","대치1동","대치2동","대치3동", "대치4동","역삼동","역삼1동","역삼2동","도곡동","도곡1동","도곡2동", "개포동","개포1동","개포2동", "개포3동","개포4동","일원본동", "일원동","일원1동","일원2동", "수서동","세곡동"])

# %%
b = set(a)

# %%
df['gu']
# Out:
# 0         강남구
# 1         강남구
# 2         강남구
# 3         강남구
# 4         강남구
# 5         강남구
# 6         강남구
# 7         강남구
# 8         강남구
# 9         강남구
# 10        강남구
# 11        강남구
# 12        강남구
# 13        강남구
# 14        강남구
# 15        강남구
# 16        강남구
# 17        강남구
# 18        강남구
# 19        강남구
# 20        강남구
# 21        강남구
# 22        강남구
# 23        강남구
# 24        강남구
# 25        강남구
# 26        강남구
# 27        강남구
# 28        강남구
# 29        강남구
#          ...
# 429436    중랑구
# 429437    중랑구
# 429438    중랑구
# 429439    중랑구
# 429440    중랑구
# 429441    중랑구
# 429442    중랑구
# 429443    중랑구
# 429444    중랑구
# 429445    중랑구
# 429446    중랑구
# 429447    중랑구
# 429448    중랑구
# 429449    중랑구
# 429450    중랑구
# 429451    중랑구
# 429452    중랑구
# 429453    중랑구
# 429454    중랑구
# 429455    중랑구
# 429456    중랑구
# 429457    중랑구
# 429458    중랑구
# 429459    중랑구
# 429460    중랑구
# 429461    중랑구
# 429462    중랑구
# 429463    중랑구
# 429464    중랑구
# 429465    중랑구
# ...

# %%
b
# Out:
# {'개포1동',
#  '개포2동',
#  '개포3동',
#  '개포4동',
#  '개포동',
#  '논현1동',
#  '논현2동',
#  '논현동',
#  '대치1동',
#  '대치2동',
#  '대치3동',
#  '대치4동',
#  '대치동',
#  '도곡1동',
#  '도곡2동',
#  '도곡동',
#  '삼성1동',
#  '삼성2동',
#  '삼성동',
#  '세곡동',
#  '수서동',
#  '신사동',
#  '압구정1동',
#  '압구정2동',
#  '역삼1동',
#  '역삼2동',
#  '역삼동',
#  '일원1동',
#  '일원2동',
#  '일원동',
#  '일원본동',
#  '청담1동',
#  '청담2동',
#  '청담동'}

# %%
df[df.isin(b)]
# Out:
#         price_per_area  price  con_year  year dong aptnm  month  dat  area  \
# 0                  NaN    NaN       NaN   NaN  개포동   NaN    NaN  NaN   NaN
# 1                  NaN    NaN       NaN   NaN  개포동   NaN    NaN  NaN   NaN
# 2                  NaN    NaN       NaN   NaN  개포동   NaN    NaN  NaN   NaN
# 3                  NaN    NaN       NaN   NaN  개포동   NaN    NaN  NaN   NaN
# 4                  NaN    NaN       NaN   NaN  개포동   NaN    NaN  NaN   NaN
# 5                  NaN    NaN       NaN   NaN  개포동   NaN    NaN  NaN   NaN
# 6                  NaN    NaN       NaN   NaN  개포동   NaN    NaN  NaN   NaN
# 7                  NaN    NaN       NaN   NaN  개포동   NaN    NaN  NaN   NaN
# 8                  NaN    NaN       NaN   NaN  개포동   NaN    NaN  NaN   NaN
# 9                  NaN    NaN       NaN   NaN  개포동   NaN    NaN  NaN   NaN
# 10                 NaN    NaN       NaN   NaN  개포동   NaN    NaN  NaN   NaN
# ...

# %%
df[df.isin(b)].price_per_area.mean()
# Out:
# nan

# %%
df[df.dong in (b)]

# %%
[1, 2, 3] in [[1,2,3],4]
# Out:
# True

# %%
df.dong in (b) # isin을 함수형 패러다임을 만든 이유
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-5e3660b9ea9e> in <module>()
# ----> 1 df.dong in (b)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __hash__(self)
#    1490     def __hash__(self):
#    1491         raise TypeError('{0!r} objects are mutable, thus they cannot be'
# -> 1492                         ' hashed'.format(self.__class__.__name__))
#    1493
#    1494     def __iter__(self):
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed

# %%
list(map(lambda x:x in b, df.dong)) #isin을 만듬
# Out:
# [True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
# ...

# %%
# 전체 칼람중에 내가원하는 칼럼이 있냐 없냐 
#isin
